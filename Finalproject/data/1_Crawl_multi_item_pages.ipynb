# %%
import pandas as pd
raw_data_df = pd.read_csv('vnexpress_foods_detail.csv')

# Mask
mask = raw_data_df.apply(
    lambda row: row['step'] in ([], "[]"),
    axis=1
)
# Create a new DataFrame with the filtered rows
empty_rows_df = raw_data_df[mask].reset_index(drop=True)

display(empty_rows_df)

print(f"{len(empty_rows_df)}")
# Out:
#                                                  link  \
# 0   https://vnexpress.net/cach-che-bien-vai-mon-au...
# 1   https://vnexpress.net/nhung-mon-ngon-cho-mua-h...
# 2   https://vnexpress.net/3-mon-ngon-de-lam-431145...
# 3   https://vnexpress.net/bien-tau-voi-mon-canh-43...
# 4   https://vnexpress.net/cac-mon-an-dam-huong-que...
# ..                                                ...
# 64  https://vnexpress.net/sinh-to-tu-rau-qua-43112...
# 65  https://vnexpress.net/mon-trang-mieng-4311313....
# 66  https://vnexpress.net/rau-cu-kho-chao-4325208....
# 67  https://vnexpress.net/mot-so-mon-an-sang-ngon-...
# 68  https://vnexpress.net/bien-com-nguoi-thanh-ban...
#
#                    type_of_food                                     title  \
# 0            Món ngon hàng ngày         Cách chế biến vài món Âu đơn giản
# 1            Món ngon hàng ngày            Những món ngon cho mùa heo may
# 2            Món ngon hàng ngày                         3 món ngon dễ làm
# 3            Món ngon hàng ngày                     Biến tấu với món canh
# 4            Món ngon hàng ngày                  Các món ăn đậm hương quê
# ..                          ...                                       ...
# 64   Món tráng miệng, giải khát                        Sinh tố từ rau quả
# 65   Món tráng miệng, giải khát                           Món tráng miệng
# 66  Thực đơn cho ngày nắng nóng                           Rau củ kho chao
# 67            Bữa sáng đơn giản                   Một số món ăn sáng ngon
# 68            Bữa sáng đơn giản  Biến cơm nguội thành bánh phô mai đút lò
#
#                                           description author_name cook_time  \
# 0   Các món ăn Âu dưới đây mang phong cách pha trộ...         NaN       NaN
# 1   Canh rong biển sườn non, bò kho ớt, bí đỏ xào ...         NaN       NaN
# 2   Những món ăn hấp dẫn và đầy đủ dưỡng chất với ...         NaN       NaN
# 3   Canh bắp và canh mướp trứng đều vừa giàu dinh ...         NaN       NaN
# 4   Mang hương vị đặc trưng của biển, những món ăn...         NaN       NaN
# ..                                                ...         ...       ...
# 64  Ngon, có lợi cho sức khỏe là công dụng c...         NaN       NaN
# 65  Dưa hấu trộn mật ong và đào ngâm rượu vang là ...         NaN       NaN
# 66  Món rau củ có vị béo ngậy và thơm đặc trưng củ...         NaN       NaN
# 67  Nhịp sống vội vã đôi khi làm bạn quên bữa ăn q...         NaN       NaN
# 68  Bạn có thể tận dụng cơm nguội làm thành cơm ph...         NaN   30 phút
#
#    num_of_people calories  num_of_ingredients  \
# 0            NaN      NaN                   9
# 1            NaN      NaN                   6
# 2            NaN      NaN                   6
# 3            NaN      NaN                   3
# 4            NaN      NaN                   7
# ..           ...      ...                 ...
# 64           NaN      NaN                   7
# 65           NaN      NaN                   4
# 66           NaN      NaN                   5
# 67           NaN      NaN                   9
# 68           NaN      NaN                   6
#
#                                           ingredients step note  \
# 0   ['Tôm', 'Nghêu', 'Mực', 'Mỳ Ý', 'Thịt bò', 'Cơ...   []   []
# 1   ['Sườn non', 'Rong biển', 'Bò', 'Bí đỏ', 'Nghê...   []   []
# 2   ['Khoai tây', 'Thịt bò', 'Cá hú', 'Tiêu xanh',...   []   []
# 3              ['Ngô ngọt', 'Mướp hương', 'Trứng gà']   []   []
# 4   ['Ốc bươu ta', 'Giò sống', 'Gạo nếp', 'Cá rô đ...   []   []
# ..                                                ...  ...  ...
# 64  ['Bắp cải', 'Táo', 'Rau cần', 'Cà rốt', 'Cần t...   []   []
# 65   ['Dưa hấu', 'Mật ong', 'Đào', 'Rượu vang trắng']   []   []
# 66  ['Chao ớt ngon: 3-4 viên kèm nước ngâm chao', ...   []   []
# 67  ['Thịt xông khói', 'Dưa vàng', 'Thịt băm', 'Mì...   []   []
# 68  ['Cơm nguội: 250 gr', 'Trứng gà; 1 quả', 'Cà c...   []   []
#
#                              post_date
# 0   Thứ hai, 22/11/2021, 10:22 (GMT+7)
# 1   Thứ năm, 18/11/2021, 15:44 (GMT+7)
# 2   Thứ năm, 18/11/2021, 15:38 (GMT+7)
# 3    Thứ tư, 17/11/2021, 16:16 (GMT+7)
# 4    Thứ tư, 17/11/2021, 15:57 (GMT+7)
# ..                                 ...
# 64   Thứ ba, 26/10/2021, 11:18 (GMT+7)
# 65   Thứ ba, 26/10/2021, 11:01 (GMT+7)
# 66     Thứ tư, 7/7/2021, 00:11 (GMT+7)
# 67  Thứ hai, 22/11/2021, 10:39 (GMT+7)
# 68    Thứ ba, 20/7/2021, 02:15 (GMT+7)
#
# [69 rows x 13 columns]
# 69

# %% [markdown]
# ### crawl data from multi-item websites

# %%
import requests
from bs4 import BeautifulSoup
from typing import List
import re

# %%
def safe_text(node):
    return node.get_text(strip=True) if node else None

# %%
def normalize_ingredient_block(text: str) -> List[str]:
    if not text:
        return []
    text = text.replace("Gia vị:", ",")
    items = [t.strip(" .;") for t in text.split(",")]
    return [i for i in items if i]

# %%
def normalize_steps_block(raw_steps: List[str]) -> List[str]:
    """
    Normalize the cooking step list:
    - Merge all text from raw_steps
    - Split by '-' or new line
    - If the paragraph is long without bullets, split by '. '
    - Remove empty spaces, strip extra punctuation
    - Number 'Step 1:', 'Step 2:', ...
    """
    flat = []
    for s in raw_steps:
        if not s:
            continue
        s = s.strip()
        # Prioritize separation by bullet '-', or new line
        parts = re.split(r"[-•\n]+", s)
        for p in parts:
            p = p.strip(" .;:-")
            if p and not p.lower().startswith("cách làm"):
                flat.append(p)

    # If there is only 1 long paragraph → split by sentence
    if len(flat) == 1 and ". " in flat[0]:
        sentences = [sen.strip(" .;") for sen in flat[0].split(". ") if sen.strip()]
        flat = sentences

    return [f"Bước {i+1}: {p}" for i, p in enumerate(flat)]

# %%
def get_food_detail(url: str, category: str) -> List[dict]:
    try:
        resp = requests.get(url, timeout=10)
        resp.encoding = "utf-8"
        soup = BeautifulSoup(resp.text, "html.parser")
    except Exception as e:
        print(f"[ERROR] {url}: {e}")
        return []

    # ==================== Metadata to all items on the page ====================
    description_tag = soup.find("p", class_="description")
    author_tag = soup.select_one("div.name b")
    date_tag = soup.find("span", class_="date")

    items_tag = soup.find("div", class_="status flex")
    time, num_of_people, calories = None, None, None
    
    if items_tag:
        for item in items_tag.find_all("p", class_="itemt"):
            text = item.get_text(strip=True)
            if "phút" in text or "giờ" in text:
                time = text
            elif "người" in text:
                num_of_people = text
            elif "kcal" in text or "calo" in text:
                calories = text

    notes = []
    extra_info = soup.find("div", class_="extra_info")
    if extra_info:
        note_section = extra_info.find("ol") or extra_info.find("ul")
        if note_section:
            for li in note_section.find_all("li"):
                t = li.get_text(separator=" ", strip=True)
                if t:
                    notes.append(t)

    # ==================== MULTI-RECIPE PARSING ====================
    content = soup.find("div", class_="fck_detail")
    if not content:
        return []

    recipes = []
    current_title = None
    current_ingredients_blocks = []  # each block is a raw str, later normalized
    current_steps_blocks = []  # raw blocks

    # iterate over p elements in content to preserve order
    for elem in content.find_all("p"):
        classes = elem.get("class", [])
        text = elem.get_text(separator=" ", strip=True)
        if not text:
            continue

        if "SubTitle" in classes:
            # finalize previous
            if current_title:
                ingredients_list = []
                for ib in current_ingredients_blocks:
                    ingredients_list.extend(normalize_ingredient_block(ib))
                steps_list = normalize_steps_block(current_steps_blocks)

                result = {
                    "link": url,
                    "type_of_food": category,
                    "title": current_title,
                    "description": safe_text(description_tag),
                    "author_name": safe_text(author_tag),
                    "cook_time": time,
                    "num_of_people": num_of_people,
                    "calories": calories,
                    "num_of_ingredients": len(ingredients_list) if ingredients_list else None,
                    "ingredients": ingredients_list,
                    "step": steps_list,
                    "note": notes,
                    "post_date": safe_text(date_tag),
                }
                recipes.append(result)

            # start new recipe
            current_title = text
            current_ingredients_blocks = []
            current_steps_blocks = []

        elif "Normal" in classes:
            low = text.lower()
            # identify ingredient block
            if low.startswith("nguyên liệu"):
                # keep the whole line to be normalized later
                _, sep, rest = text.partition(":")
                if sep:
                    current_ingredients_blocks.append(rest.strip())
                else:
                    # no colon — keep entire line
                    current_ingredients_blocks.append(text)
            elif low.startswith("cách làm") or low.startswith("cách chế biến") or low.startswith("thực hiện"):
                # extract after colon if present
                _, sep, rest = text.partition(":")
                if sep and rest.strip():
                    current_steps_blocks.append(rest.strip())
                else:
                    # maybe steps start in subsequent Normal paragraphs
                    # append empty marker to signal steps started
                    current_steps_blocks.append("")
            else:
                # context sensitive: if we already saw steps section, append there,
                # otherwise treat as ingredient continuation
                if current_steps_blocks:
                    current_steps_blocks.append(text)
                else:
                    current_ingredients_blocks.append(text)

    # finalize last recipe
    if current_title:
        ingredients_list = []
        for ib in current_ingredients_blocks:
            ingredients_list.extend(normalize_ingredient_block(ib))
        steps_list = normalize_steps_block(current_steps_blocks)

        result = {
            "link": url,
            "type_of_food": category,
            "title": current_title,
            "description": safe_text(description_tag),
            "author_name": safe_text(author_tag),
            "cook_time": time,
            "num_of_people": num_of_people,
            "calories": calories,
            "num_of_ingredients": len(ingredients_list) if ingredients_list else None,
            "ingredients": ingredients_list,
            "step": steps_list,
            "note": notes,
            "post_date": safe_text(date_tag),
        }
        recipes.append(result)

    return recipes

# %%
all_foods_details = []

for index, row in empty_rows_df.iterrows():
    url = row['link']
    category = row['type_of_food']
    food_details = get_food_detail(url, category)
    if food_details:
        print(f"[INFO] Fetched {len(food_details)} recipes from {url}")
        for detail in food_details:
            print(detail['title'])
            all_foods_details.append(detail)
    else:
        print(f"[WARN] No details found for {url}")
# Out:
# [INFO] Fetched 4 recipes from https://vnexpress.net/cach-che-bien-vai-mon-au-don-gian-4311539.html
# Lẩu hải sản Pháp
# Mỳ bò băm
# Cơm chiên nho
# Hàu sốt bơ chanh
# [INFO] Fetched 4 recipes from https://vnexpress.net/nhung-mon-ngon-cho-mua-heo-may-4311484.html
# Canh rong biển sườn non
# Bò kho ớt
# Bí đỏ xào nghêu
# Ếch tay cầm
# [INFO] Fetched 3 recipes from https://vnexpress.net/3-mon-ngon-de-lam-4311455.html
# Khoai tây xào thịt bò
# Cá hú kho tiêu xanh
# Mít non xào tỏi
# [INFO] Fetched 2 recipes from https://vnexpress.net/bien-tau-voi-mon-canh-4311501.html
# Canh bắp
# Canh mướp trứng
# [INFO] Fetched 4 recipes from https://vnexpress.net/cac-mon-an-dam-huong-que-4311479.html
# Nem ốc
# Xôi rô đồng
# Gỏi sứa
# Canh ghẹ rau muống
# [INFO] Fetched 2 recipes from https://vnexpress.net/hai-mon-ngon-chua-benh-4311475.html
# Chè củ cải
# Rau cải xào nấm
# [INFO] Fetched 5 recipes from https://vnexpress.net/bien-tau-mon-gan-4311449.html
# Gan ngỗng xốt dâu tây
# Gan ngỗng xốt giấm đen
# Gan vịt rán vàng xốt chanh
# Gan gà rán muối ớt
# Pa-tê gan lợn
# [INFO] Fetched 3 recipes from https://vnexpress.net/quen-la-voi-tom-4311462.html
# Tôm xốt coca cola
# Tôm trộn cải mầm dầu giấm
# Canh chua tôm nõn
# [INFO] Fetched 2 recipes from https://vnexpress.net/hai-mon-ngay-thuong-ngon-mieng-4311469.html
# Bí cuốn tôm thịt
# Đậu hũ nhồi tôm sốt chua cay
# [INFO] Fetched 2 recipes from https://vnexpress.net/hai-mon-ngon-mang-vi-ngot-cam-thao-4311314.html
# Giò lợn hầm
# Chè đậu cam thảo
# [INFO] Fetched 4 recipes from https://vnexpress.net/nhung-mon-ngon-dam-da-vi-moi-4311459.html
# Gà nướng lá chanh
# Salad trứng cua
# Canh củ cải hầm xương
# Chuối rim mật nước cốt dừa
# [INFO] Fetched 3 recipes from https://vnexpress.net/mon-ngon-voi-ca-chua-4311445.html
# Cà bi kho cá bống trứng
# Cà chua nhồi óc lợn
# Bắp chiên phô mai xốt cà chua
# [INFO] Fetched 2 recipes from https://vnexpress.net/mon-ngon-la-mieng-4311432.html
# Tôm càng cá ngừ cuộn rong biển
# Chả giò mực
# [INFO] Fetched 3 recipes from https://vnexpress.net/bua-com-dam-mau-sac-4311435.html
# Cải thìa xốt bắp Mỹ
# Mực hấp xốt cay
# Cải thảo xào khô
# [INFO] Fetched 3 recipes from https://vnexpress.net/dam-da-huong-vi-mon-cay-4311422.html
# Cá thu Nhật nấu ngót
# Salad đậu cô ve
# Mực chiên sả
# [INFO] Fetched 4 recipes from https://vnexpress.net/cac-mon-tu-com-quen-ma-la-4311400.html
# Cơm bát bửu
# Cơm xá xíu
# Cơm hấp
# Cơm nướng
# [INFO] Fetched 3 recipes from https://vnexpress.net/thuc-don-la-mieng-ma-bat-mat-4311409.html
# Sò điệp xào ớt
# Súp kem hai màu
# Gà già sốt cà chua
# [INFO] Fetched 4 recipes from https://vnexpress.net/bua-an-am-cung-voi-4-mon-de-lam-4311410.html
# Cá trứng nướng xốt me
# Canh khoai sọ rau nhút
# Cải thảo xào thịt nạc
# Chè trôi nước
# [INFO] Fetched 3 recipes from https://vnexpress.net/hap-dan-tu-nhung-mon-quen-4311403.html
# Bông cải xào thịt bò
# Canh măng chua cá lóc
# Cá rô kho khế chua
# [INFO] Fetched 4 recipes from https://vnexpress.net/thuc-don-cho-nguoi-ban-ron-4311405.html
# Cải ngồng xào tỏi
# Canh riêu cá chép
# Đậu hũ rán tẩm hành
# Chả lụa kho tiêu
# [INFO] Fetched 4 recipes from https://vnexpress.net/tro-tai-voi-cac-mon-ran-nong-4311408.html
# Khoai tây phô mai
# Chả cá trứng muối
# Giò sống bọc trứng cút
# Tôm cuốn khoai cao
# [INFO] Fetched 3 recipes from https://vnexpress.net/vai-mon-ngon-cho-bua-com-mua-lanh-4311415.html
# Lưỡi heo sốt chua ngọt
# Cá bống mú hấp hành lá
# Chim cút tiềm ngũ quả
# [INFO] Fetched 3 recipes from https://vnexpress.net/3-mon-salad-mat-lanh-4311299.html
# Salad rau
# Salad hoa quả
# Salad cà chua, dưa chuột
# [INFO] Fetched 3 recipes from https://vnexpress.net/4-mon-ngon-tu-khoai-4311376.html
# Chả khoai
# Bò cuộn khoai môn bán xù
# Bánh mì khoai nướng
# [INFO] Fetched 2 recipes from https://vnexpress.net/mon-la-tu-dua-chuot-4311339.html
# Miến trộn dưa chuột
# Dưa chuột xào thịt
# [INFO] Fetched 3 recipes from https://vnexpress.net/nhung-mon-rau-hap-dan-be-4311316.html
# Sa lát gà - rau
# Bột lê rau quả
# Súp cà chua
# [INFO] Fetched 3 recipes from https://vnexpress.net/3-mon-la-mieng-de-lam-4311401.html
# Canh gà lá giang
# Dưa leo trộn sò lông
# Bò viên sốt cà chua
# [INFO] Fetched 3 recipes from https://vnexpress.net/3-mon-voi-ngheu-4311423.html
# Nghêu hấp thái
# Nghêu hấp sả
# Nghêu xào sa tế
# [INFO] Fetched 5 recipes from https://vnexpress.net/5-mon-om-ham-nong-ngay-lanh-4311243.html
# Cà tím om thịt lợn
# Cá trê om hoa chuối
# Sườn non om dưa (cải) chua
# Giò lợn om mía đậu
# Gà om nước dừa
# [INFO] Fetched 2 recipes from https://vnexpress.net/hai-mon-ngon-lam-dep-da-4311470.html
# Tôm rán lúa mạch
# Atiso trộn
# [INFO] Fetched 5 recipes from https://vnexpress.net/nhung-mon-ngon-che-bien-tu-sen-4311424.html
# Gỏi ngó sen
# Kim chi củ sen
# Ngó sen xào tôm tươi
# Canh củ sen hầm giò heo
# Canh ngó sen
# [WARN] No details found for https://vnexpress.net/suon-heo-xot-cam-4311374.html
# [INFO] Fetched 4 recipes from https://vnexpress.net/cac-mon-ngon-tu-thit-ech-4311324.html
# Ếch xào cải chua
# Canh ếch
# Ếch trộn rau nhút
# Ếch kho tộ
# [INFO] Fetched 3 recipes from https://vnexpress.net/3-mon-cho-nguoi-nghen-4311290.html
# Tôm nấu riêu
# Canh nấm thịt bò
# Soup tôm vị gừng
# [INFO] Fetched 4 recipes from https://vnexpress.net/bat-mat-va-ngon-mieng-voi-ot-chuong-4311206.html
# Sò điệp xào ớt chuông
# Cá nướng sốt ớt chuông
# Ớt chuông nhồi thịt
# Ớt chuông xào chay
# [INFO] Fetched 4 recipes from https://vnexpress.net/4-mon-ngon-tu-hoa-thien-ly-4311207.html
# Thiên lý xào trứng và thịt bò
# Thiên lý xào sò điệp
# Gỏi thiên lý nghêu và tôm
# Canh thiên lý cua đồng
# [INFO] Fetched 3 recipes from https://vnexpress.net/mon-la-hai-san-4311204.html
# Chả mực chiên xù
# Tôm chiên khoai môn
# Hải sản nhồi dưa leo
# [WARN] No details found for https://vnexpress.net/canh-thit-bo-nam-huong-4311105.html
# [WARN] No details found for https://vnexpress.net/salad-nga-rau-cu-4311104.html
# [WARN] No details found for https://vnexpress.net/cach-lam-banh-goi-don-gian-4311158.html
# [WARN] No details found for https://vnexpress.net/ga-cuon-sot-cam-sanh-4311153.html
# [INFO] Fetched 2 recipes from https://vnexpress.net/thom-ngon-tu-thit-ech-4311032.html
# Ếch tẩm vừng rán
# Ếch sốt chua ngọt
# [WARN] No details found for https://vnexpress.net/cac-mon-ngon-tu-top-mo-4328215.html
# [WARN] No details found for https://vnexpress.net/lam-trung-hap-mem-nhu-banh-pudding-bang-noi-chien-khong-dau-4325188.html
# [WARN] No details found for https://vnexpress.net/xoi-gac-deo-ngot-4325185.html
# [WARN] No details found for https://vnexpress.net/cach-lam-mon-mong-gio-ngam-sa-tac-4298416.html
# [INFO] Fetched 4 recipes from https://vnexpress.net/cac-mon-ngon-lam-tu-nha-dam-4311518.html
# Súp nha đam hải sản
# Nha đam nấu đuôi bò
# Gỏi nha đam
# Chè nha đam
# [INFO] Fetched 4 recipes from https://vnexpress.net/cac-mon-an-che-bien-voi-me-4311466.html
# Cua rang me
# Tôm rang me
# Ốc mỡ rang me
# Sườn non sốt me
# [INFO] Fetched 4 recipes from https://vnexpress.net/cac-mon-ngon-dai-khach-4311458.html
# Vịt nướng lá lốt
# Gà rút xương nhồi
# Nghêu nướng lá dứa
# Ếch gói lá sen
# [INFO] Fetched 2 recipes from https://vnexpress.net/vi-ngot-tu-ngo-non-4311443.html
# Chả hấp ngô
# Súp kem ngô
# [INFO] Fetched 2 recipes from https://vnexpress.net/hai-mon-ngon-tu-buoi-4311472.html
# Nước ép bưởi
# Gỏi bưởi chanh dây
# [INFO] Fetched 1 recipes from https://vnexpress.net/hai-mon-ca-nuong-de-lam-4311391.html
# Cá hồi nướng muối ớt (kiểu Indo)
# [INFO] Fetched 3 recipes from https://vnexpress.net/mon-man-tu-hoa-qua-4311321.html
# Gỏi mãng cầu
# Lẩu hoa quả
# Chả giò hoa quả
# [INFO] Fetched 3 recipes from https://vnexpress.net/la-mieng-voi-nam-4311438.html
# Salad nấm kim châm
# Cơm rang nấm canba
# Lẩu nấm bụng dê
# [WARN] No details found for https://vnexpress.net/ngao-nuong-mo-hanh-4311301.html
# [INFO] Fetched 3 recipes from https://vnexpress.net/cay-cay-mon-oc-4311274.html
# Ốc móng tay trộn chua cay
# Ốc đỏ nấu sữa
# Ốc giác nấu cà ri
# [WARN] No details found for https://vnexpress.net/cach-lam-bun-thang-don-gian-4311156.html
# [WARN] No details found for https://vnexpress.net/banh-canh-khoai-xat-vit-xiem-4325184.html
# [WARN] No details found for https://vnexpress.net/che-bien-mot-con-ga-thanh-10-mon-kieu-a-au-4298480.html
# [WARN] No details found for https://vnexpress.net/doi-vi-voi-mon-ga-nuong-mat-ong-4298490.html
# [WARN] No details found for https://vnexpress.net/mia-uop-hoa-buoi-thuc-qua-thanh-tao-thang-3-4434775.html
# [WARN] No details found for https://vnexpress.net/5-bien-tau-tu-khoai-lang-tim-4325149.html
# [WARN] No details found for https://vnexpress.net/ba-buoc-lam-banh-khoai-lang-tim-nung-ninh-4325164.html
# [WARN] No details found for https://vnexpress.net/bon-loai-banh-ngot-ngao-mat-lanh-4311379.html
# [INFO] Fetched 4 recipes from https://vnexpress.net/sinh-to-tu-rau-qua-4311296.html
# Bắp cải và táo
# Yoghurt và rau cần
# Cà rốt và cần tây
# Đu đủ và bắp cải tím
# [INFO] Fetched 2 recipes from https://vnexpress.net/mon-trang-mieng-4311313.html
# Dưa hấu trộn mật ong
# Đào dầm rượu vang
# [WARN] No details found for https://vnexpress.net/rau-cu-kho-chao-4325208.html
# [WARN] No details found for https://vnexpress.net/mot-so-mon-an-sang-ngon-4311573.html
# [WARN] No details found for https://vnexpress.net/bien-com-nguoi-thanh-banh-pho-mai-dut-lo-4325128.html

# %%
all_foods_details
# Out:
# [{'link': 'https://vnexpress.net/cach-che-bien-vai-mon-au-don-gian-4311539.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Lẩu hải sản Pháp',
#   'description': 'Các món ăn Âu dưới đây mang phong cách pha trộn Âu - Á, vừa không làm mất đi hương vị gốc của món ăn vừa không ngán.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 9,
#   'ingredients': ['Tôm 200 g',
#    'nghêu 200 g',
#    'mực 200 g',
#    'cà 200 g',
#    'nghệ tây',
#    'cà chua 1 trái',
#    'rượu vang 100 ml',
#    'nước đường 1 lít',
#    'rau mùi 20 g'],
#   'step': ['Bước 1: Xào cà chua cho thơm, đổ rượu vang vào đun sắc cho hết cồn, cho tiếp nước dùng vào',
#    'Bước 2: Bỏ nghệ tây, rau mùi, nêm gia vị vừa ăn',
#    'Bước 3: Khi dùng, đun nước sôi, cho hải sản vào',
#    'Bước 4: Dùng với các loại rau ưa thích',
#    'Bước 5: Có thể ăn với bún hay mì tùy thích'],
#   'note': [],
#   'post_date': 'Thứ hai, 22/11/2021, 10:22 (GMT+7)'},
#  {'link': 'https://vnexpress.net/cach-che-bien-vai-mon-au-don-gian-4311539.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Mỳ bò băm',
#   'description': 'Các món ăn Âu dưới đây mang phong cách pha trộn Âu - Á, vừa không làm mất đi hương vị gốc của món ăn vừa không ngán.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 8,
#   'ingredients': ['Mỳ Ý 100 g',
#    'cà chua 200 g',
#    'thịt bò 200 g',
#    'hành tây 20 g',
#    'tỏi 20 g',
#    'cà chua hộp 20 g',
#    'muối',
#    'tiêu'],
#   'step': ['Bước 1: Luộc mì Ý trong nước sôi khoảng 8 phút. Lấy ra, rửa sạch với nước ấm. Bắc chảo lên bếp cho nóng rồi xào hành tây với tỏi cho thơm, cho cà chua băm nhuyễn, thịt bò băm nhuyễn. Bỏ cà chua hộp vào xào chung cho thơm, nêm gia vị vừa ăn',
#    'Bước 2: Tưới sốt này lên mỳ dùng nóng'],
#   'note': [],
#   'post_date': 'Thứ hai, 22/11/2021, 10:22 (GMT+7)'},
#  {'link': 'https://vnexpress.net/cach-che-bien-vai-mon-au-don-gian-4311539.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Cơm chiên nho',
#   'description': 'Các món ăn Âu dưới đây mang phong cách pha trộn Âu - Á, vừa không làm mất đi hương vị gốc của món ăn vừa không ngán.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 7,
#   'ingredients': ['Cơm trắng 200 g',
#    'nho 100 g',
#    'cà rốt 30 g',
#    'bắp Mỹ 30 g',
#    'bơ 20 g',
#    'ngò tây 10 g',
#    'muối tiêu'],
#   'step': ['Bước 1: Đặt chảo lên bếp, chờ chảo nóng cho bơ vào, xào nho, cà rốt, bắp Mỹ cho thơm',
#    'Bước 2: Cho cơm trắng vào xào tiếp, nêm gia vị vừa ăn',
#    'Bước 3: Rắc ngò tây lên trên, xúc ra đĩa, dùng nóng'],
#   'note': [],
#   'post_date': 'Thứ hai, 22/11/2021, 10:22 (GMT+7)'},
#  {'link': 'https://vnexpress.net/cach-che-bien-vai-mon-au-don-gian-4311539.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Hàu sốt bơ chanh',
#   'description': 'Các món ăn Âu dưới đây mang phong cách pha trộn Âu - Á, vừa không làm mất đi hương vị gốc của món ăn vừa không ngán.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 6,
#   'ingredients': ['Hàu 1 kg',
#    'bơ 50 g',
#    'chanh 10 g',
#    'đường 10 g',
#    'ngò tây 5 g',
#    'hành tây 10 g'],
#   'step': ['Bước 1: Hàu rửa sạch, tách vỏ ra làm đôi. Hành tây bằm nhuyễn, vắt nước chanh, sau đó hòa với đường cho tan đều. Bắc chảo lên bếp, chờ cho chảo nóng rồi xào hành tây cho thơm, cho nước chanh vào, nêm gia vị vừa ăn, sau đó cho tiếp bơ vào',
#    'Bước 2: Đổ hỗn hợp này lên trên hàu, đem đút lò khoảng 10 phút, lấy ra dùng nóng'],
#   'note': [],
#   'post_date': 'Thứ hai, 22/11/2021, 10:22 (GMT+7)'},
#  {'link': 'https://vnexpress.net/nhung-mon-ngon-cho-mua-heo-may-4311484.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Canh rong biển sườn non',
#   'description': 'Canh rong biển sườn non, bò kho ớt, bí đỏ xào nghêu và ếch tay cầm - những món ăn với hương vị đậm đà - sẽ làm cho bữa cơm gia đình bạn trong những ngày chớm thu thêm ấm cúng.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 8,
#   'ingredients': ['200 g sườn non',
#    '50 rong biển (loại nấu canh)',
#    '1 miếng đậu hũ trắng',
#    '20 g củ gừng',
#    '1 cọng hành lá',
#    'bột nêm',
#    'đường',
#    'nước mắm'],
#   'step': ['Bước 1: Sườn non chà muối cho sạch, rửa rồi để ráo, chặt khúc dài 2cm. Rong biển ngâm vào nước cho mềm, vớt ra, để ráo. Đậu hũ trắng thái miếng vuông, cạnh 1,5cm. Gừng gọt vỏ, thái sợi nhuyễn, hành lá thái xéo',
#    'Bước 2: Đun sôi 1 lít nước, cho sườn non vào đun sôi, hớt bọt. Đun khoảng 15 phút để sườn non chín mềm, cho rong biển và đậu hũ trắng vào, đun thêm 2 phút. Nêm 1 thìa cà phê bột nêm, 1/2 thìa cà phê đường và 1 thìa cà phê nước mắm. Tắt bếp, thả gừng vào. Múc canh ra tô, bày sườn non, rong biển và đậu hũ trắng sao cho mỗi thứ một góc. Sau đó, rắc đều hành lá lên'],
#   'note': [],
#   'post_date': 'Thứ năm, 18/11/2021, 15:44 (GMT+7)'},
#  {'link': 'https://vnexpress.net/nhung-mon-ngon-cho-mua-heo-may-4311484.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Bò kho ớt',
#   'description': 'Canh rong biển sườn non, bò kho ớt, bí đỏ xào nghêu và ếch tay cầm - những món ăn với hương vị đậm đà - sẽ làm cho bữa cơm gia đình bạn trong những ngày chớm thu thêm ấm cúng.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 8,
#   'ingredients': ['300 g bắp bò',
#    '100 g gừng non',
#    '5 củ hành tím',
#    '2 quả ớt sừng',
#    'bột nêm',
#    'đường',
#    'tiêu',
#    'nước mắm'],
#   'step': ['Bước 1: Bắp bò luộc chín, thái khoanh mỏng. Ướp với 4 thìa súp nước mắm, 1 thìa súp đường, 1thìa cà phê bột nêm và 1 thìa cà phê tiêu',
#    'Bước 2: Gừng non rửa sạch, cạo vỏ, đê nguyên củ. Ớt sừng thái khúc dài 2 cm (có thể bỏ hạt). Hành tím bóc vỏ, củ nhỏ để nguyên, củ lớn chẻ đôi theo chiều ngang. Bắp bò cho vào nồi, kho trên lửa vừa. Khi bò săn lại, cho gừng và ớt vào kho chung. Khoảng 5 phút sau thì bắp bò ngấm nhưng còn hơi dai, cho tiếp hành tím vào, kho thêm 2 phút, tắt bếp'],
#   'note': [],
#   'post_date': 'Thứ năm, 18/11/2021, 15:44 (GMT+7)'},
#  {'link': 'https://vnexpress.net/nhung-mon-ngon-cho-mua-heo-may-4311484.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Bí đỏ xào nghêu',
#   'description': 'Canh rong biển sườn non, bò kho ớt, bí đỏ xào nghêu và ếch tay cầm - những món ăn với hương vị đậm đà - sẽ làm cho bữa cơm gia đình bạn trong những ngày chớm thu thêm ấm cúng.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 9,
#   'ingredients': ['100 g thịt nghêu',
#    '350 g bí đỏ',
#    '100 g nấm đông cô (loại tươi)',
#    '50 g củ hành tây (1 củ nhỏ)',
#    '2 cọng hành lá',
#    '10 g tỏi băm',
#    'bột nêm',
#    'đường',
#    'dầu ăn'],
#   'step': ['Bước 1: Nghêu rửa sạch, để ráo. Bí gọt vỏ, dùng dao răng cưa thái thành từng khoanh dài 4 cm, ngang 0,5 cm đến 1 cm. Hành lá thái khúc dài 1,5 cm',
#    'Bước 2: Phi thơm tỏi băm với 2 thìa súp dầu ăn, cho nghêu vào đảo đều rồi cho bí đỏ và nấm đông cô vào xào cùng 3 thìa súp nước. Nêm gia vị gồm 1 thìa súp bột nêm và 2 thìa cà phê đường. Khi bí đỏ chín hơi mềm, cho hành tây vào xào thêm 1 phút, tắt bếp. Bày ra đĩa. Rắc hành lá lên'],
#   'note': [],
#   'post_date': 'Thứ năm, 18/11/2021, 15:44 (GMT+7)'},
#  {'link': 'https://vnexpress.net/nhung-mon-ngon-cho-mua-heo-may-4311484.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Ếch tay cầm',
#   'description': 'Canh rong biển sườn non, bò kho ớt, bí đỏ xào nghêu và ếch tay cầm - những món ăn với hương vị đậm đà - sẽ làm cho bữa cơm gia đình bạn trong những ngày chớm thu thêm ấm cúng.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 14,
#   'ingredients': ['1/2 kg ếch (đã lột da)',
#    '50 g ớt chuông đỏ',
#    '50 g ớt chuông vàng',
#    '50 g ớt chuông xanh',
#    '3 củ hành tím',
#    '5 g tỏi băm',
#    '10 g gừng',
#    'bột nêm',
#    'đường',
#    'tiêu',
#    'nước tương',
#    'tương ớt',
#    'hắc xì dầu',
#    'dầu ăn'],
#   'step': ['Bước 1: Ếch rửa sạch, để ráo, chặt làm tư. Ớt chuông đỏ, xanh vàng thái miếng vuông, cạnh 1,5cm. Hành tím bóc vỏ, củ lớn chẻ đôi, củ nhỏ để nguyên. Gừng gọt vỏ, thái sợi nhuyễn',
#    'Bước 2: Phi thơm tỏi băm và gừng thái sợi với 1,5 thìa súp dầu ăn. Cho ếch vào xào. Nêm gia vị gồm 1 thìa súp hắc xì dầu, 1 thìa súp nước tương, 2 thìa súp tương ớt, 1/2 thìa súp bột nêm và 1 thìa súp đường. 2 phút sau, cho 1/2 bát nước vào. Đun 3 phút, cho ớt chuông và hành tím vào xào, đảo đều. Trút vào thố đất, đun trên lửa liu riu đến khi ếch mềm, tắt bếp. Rắc 1/2 thìa cà phê tiêu'],
#   'note': [],
#   'post_date': 'Thứ năm, 18/11/2021, 15:44 (GMT+7)'},
#  {'link': 'https://vnexpress.net/3-mon-ngon-de-lam-4311455.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Khoai tây xào thịt bò',
#   'description': 'Những món ăn hấp dẫn và đầy đủ dưỡng chất với thời gian chế biến nhanh là những gì các bà nội trợ thời hiện đại cần. Khoai tây xào thịt bò, cá hú kho tiêu xanh và mít non xào tỏi là các món đáp ứng được yêu cầu này của bạn.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 8,
#   'ingredients': ['100 g phi lê thịt bò',
#    '250 g khoai tây (2 củ)',
#    '3 tép tỏi',
#    'hạt nêm',
#    'tiêu',
#    'bột năng',
#    'nước tương',
#    'dầu ăn'],
#   'step': ['Bước 1: Rửa thịt bò, để ráo, thái miếng dài 4 cm, ngang 1,5 cm, dày 0,2 cm. Ướp thịt bò với 1/2 thìa cà phê hạt nêm, 1/3 thìa cà phê tiêu, 1 thìa súp nước tương, 1/2 thìa cà phê bột năng và 1/2 thìa súp dầu ăn. Khoai tây gọt vỏ, rửa sạch, dùng dao răng cưa xắn thành từng khoanh dày 0,5 cm, sau đó xắn thanh dài. Đun nóng 1/2 bát dầu ăn, cho khoai tây vào rán giòn, vớt ra',
#    'Bước 2: Phi thơm tỏi băm. Cho thịt bò vào xào tái trên lửa lớn. Kế đó cho khoai tây vào đảo đều, tắt bếp, rắc 1/2 thìa cà phê tiêu'],
#   'note': [],
#   'post_date': 'Thứ năm, 18/11/2021, 15:38 (GMT+7)'},
#  {'link': 'https://vnexpress.net/3-mon-ngon-de-lam-4311455.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Cá hú kho tiêu xanh',
#   'description': 'Những món ăn hấp dẫn và đầy đủ dưỡng chất với thời gian chế biến nhanh là những gì các bà nội trợ thời hiện đại cần. Khoai tây xào thịt bò, cá hú kho tiêu xanh và mít non xào tỏi là các món đáp ứng được yêu cầu này của bạn.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 7,
#   'ingredients': ['3 lát cá hú (300 g)',
#    '50 g tiêu xanh',
#    '5 g ớt xay',
#    'hạt nêm',
#    'đường',
#    'nước mắm',
#    'tiêu xay'],
#   'step': ['Bước 1: Cá chà muối cho sạch, rửa lại với nước, để ráo. Tiêu xanh cắt bỏ phần cọng thừa, rửa sạch, để nguyên nhánh nhỏ',
#    'Bước 2: Ướp cá và tiêu xanh với 4 thìa súp nước mắm, 3 thìa súp đường và 2 thìa cà phê hạt nêm trong khoảng 5 đến 10 phút cho thấm gia vị. Cho cá vào nối, đun trên lửa vừa khi nước trong nồi hơi đặc sánh lại. Cho ớt vào, đun thêm 1 phút nữa, tắt bếp',
#    'Bước 3: Múc cá ra đĩa, rắc thêm tiêu xanh'],
#   'note': [],
#   'post_date': 'Thứ năm, 18/11/2021, 15:38 (GMT+7)'},
#  {'link': 'https://vnexpress.net/3-mon-ngon-de-lam-4311455.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Mít non xào tỏi',
#   'description': 'Những món ăn hấp dẫn và đầy đủ dưỡng chất với thời gian chế biến nhanh là những gì các bà nội trợ thời hiện đại cần. Khoai tây xào thịt bò, cá hú kho tiêu xanh và mít non xào tỏi là các món đáp ứng được yêu cầu này của bạn.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 8,
#   'ingredients': ['300 g mít non',
#    '6 tép tỏi',
#    '20 g lạc rang (đậu phộng)',
#    'rau quế',
#    'hạt nêm',
#    'muối',
#    'đường',
#    'dầu ăn'],
#   'step': ['Bước 1: Luộc chín mít non, rửa qua nước muối pha loãng, cắt bỏ cùi, xé miếng dày 1cm. Tỏi bóc vỏ, băm nhuyễn. Lạc rang chà sạch vỏ, giã giập. Phi thơm tỏi băm và 2 thìa súp dầu ăn. Cho mít vào đảo nhanh tay. Nêm 2 thìa cà phê hạt nêm, 1/4 thìa cà phê muối và 1/2 thìa cà phê đường. Đến khi mít chín, tắt bếp, rắc lạc rang vào, trộn đều',
#    'Bước 2: Bày ra đĩa. Cắt khúc rau quế rồi rắc lên'],
#   'note': [],
#   'post_date': 'Thứ năm, 18/11/2021, 15:38 (GMT+7)'},
#  {'link': 'https://vnexpress.net/bien-tau-voi-mon-canh-4311501.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Canh bắp',
#   'description': 'Canh bắp và canh mướp trứng đều vừa giàu dinh dưỡng vừa dễ chế biến và rất ngon. Bạn thử làm cho cả nhà thưởng thức ngay nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 7,
#   'ingredients': ['2 bắp ngô ngọt',
#    '500 g diềm thăn bò',
#    '1 củ hành khô',
#    '1 củ cà rốt',
#    '5 tai nấm hương',
#    '100 g măng lưỡi lợn đã luộc kỹ',
#    'vài cọng hành tươi'],
#   'step': ['Bước 1: Ngô để nguyên bắp chặt làm 5',
#    'Bước 2: 6 miếng. Thịt bò diềm thăn xắt quân cờ to, ướp với một chút nước mắm, đường để khoảng 10 phút. Nấm hương ngâm nước nóng cho nở, cà rốt gọt vỏ xắt khoanh tròn, măng xắt miếng vừa phải',
#    'Bước 3: Bắc chảo lên bếp, phi thơm hành, cho thịt bò vào xào săn, cho nước lạnh vào đun sôi khoảng 15 phút. Tiếp đó cho măng, ngô, cà rốt, hạt nêm vừa ăn rồi đun sôi vặn lửa nhỏ, hầm chín mềm, gần chín cho thêm nấm hương. Trước khi tắt bếp, rắc hành, ăn nóng'],
#   'note': [],
#   'post_date': 'Thứ tư, 17/11/2021, 16:16 (GMT+7)'},
#  {'link': 'https://vnexpress.net/bien-tau-voi-mon-canh-4311501.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Canh mướp trứng',
#   'description': 'Canh bắp và canh mướp trứng đều vừa giàu dinh dưỡng vừa dễ chế biến và rất ngon. Bạn thử làm cho cả nhà thưởng thức ngay nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 6,
#   'ingredients': ['1 trái mướp hương',
#    '1 quả trứng gà',
#    '1 nhánh gừng xắt sợi',
#    '1 nhánh hành tươi xắt nhỏ',
#    'hạt nêm hải sản',
#    'dầu ăn'],
#   'step': ['Bước 1: Mướp gọt vỏ, bổ đôi, xắt vát. Đập trứng ra tô, đánh bông. Bắc nồi lên bếp, đun nóng dầu ăn, cho gừng, mướp vào xào, nêm hạt nêm, nước lạnh, đun sôi, từ từ cho trứng vào, vừa rót vừa quấy nhẹ tay cho trứng bông lên',
#    'Bước 2: Canh sôi, rắc hành tươi'],
#   'note': [],
#   'post_date': 'Thứ tư, 17/11/2021, 16:16 (GMT+7)'},
#  {'link': 'https://vnexpress.net/cac-mon-an-dam-huong-que-4311479.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Nem ốc',
#   'description': 'Mang hương vị đặc trưng của biển, những món ăn dân dã dưới đây không kém phần hấp dẫn và có thể khiến cả nhà phải trầm trồ về tài nấu nướng của bạn.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 8,
#   'ingredients': ['Ốc bươu ta 1 kg',
#    'giò sống 100 g',
#    'mộc nhĩ 30 g',
#    'lá chanh',
#    'rau răm',
#    'hạt tiêu',
#    'mì chính vừa đủ',
#    'bánh đa cuốn 1 tệp'],
#   'step': ['Bước 1: Ốc làm sạch luộc chín, khêu ruột, rửa sạch và thái nhỏ',
#    'Bước 2: Mộc nhĩ đem ngâm nở, rửa sạch, thái nhỏ',
#    'Bước 3: Trộn đều các gia vị với giò sống, thịt ốc, sau đó, cuốn lại thành nem, chiên vàng trong dầu ăn nóng già',
#    'Bước 4: Nem ốc chấm với nước mắm chua ngọt rất ngon'],
#   'note': [],
#   'post_date': 'Thứ tư, 17/11/2021, 15:57 (GMT+7)'},
#  {'link': 'https://vnexpress.net/cac-mon-an-dam-huong-que-4311479.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Xôi rô đồng',
#   'description': 'Mang hương vị đặc trưng của biển, những món ăn dân dã dưới đây không kém phần hấp dẫn và có thể khiến cả nhà phải trầm trồ về tài nấu nướng của bạn.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 6,
#   'ingredients': ['Gạo nếp ngon 0',
#    '5 kg',
#    'cá rô đồng to 0',
#    '5 kg',
#    'hạt tiêu',
#    'mì chính vừa đủ'],
#   'step': ['Bước 1: Cá rô làm sạch, nướng chín, để nguội bóc lấy thịt xào với hành khô, tiêu, mì chính cho quyện đều',
#    'Bước 2: Gạo nếp ngâm kỹ, vo sạch để ráo, rắc thêm chút muối đồ chín',
#    'Bước 3: Sau đó rắc phủ thịt rô đồng đã xào chín lên mặt xôi sao cho đều, đẹp mắt'],
#   'note': [],
#   'post_date': 'Thứ tư, 17/11/2021, 15:57 (GMT+7)'},
#  {'link': 'https://vnexpress.net/cac-mon-an-dam-huong-que-4311479.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Gỏi sứa',
#   'description': 'Mang hương vị đặc trưng của biển, những món ăn dân dã dưới đây không kém phần hấp dẫn và có thể khiến cả nhà phải trầm trồ về tài nấu nướng của bạn.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 10,
#   'ingredients': ['Sứa 0',
#    '5 kg',
#    'dứa 1 quả nhỏ',
#    'khế xanh 1 quả to',
#    'chanh 1 quả',
#    'rau kinh giới',
#    'ớt',
#    'tỏi',
#    'đường',
#    'hạt tiêu vừa đủ'],
#   'step': ['Bước 1: Sứa làm sạch, trần qua nước sôi',
#    'Bước 2: Dứa gọt vỏ, bỏ mắt, thái chỉ',
#    'Bước 3: Khế xanh thái chỉ',
#    'Bước 4: Tỏi, ớt băm nhỏ vắt lấy nước cốt',
#    'Bước 5: Rau kinh giới thái nhỏ',
#    'Bước 6: Sau đó, trộn đều các nguyên liệu trên với gia vị sao cho đều, thêm chút đường, muối vừa ăn',
#    'Bước 7: Để 10 phút cho ngấm rồi bày ra đĩa'],
#   'note': [],
#   'post_date': 'Thứ tư, 17/11/2021, 15:57 (GMT+7)'},
#  {'link': 'https://vnexpress.net/cac-mon-an-dam-huong-que-4311479.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Canh ghẹ rau muống',
#   'description': 'Mang hương vị đặc trưng của biển, những món ăn dân dã dưới đây không kém phần hấp dẫn và có thể khiến cả nhà phải trầm trồ về tài nấu nướng của bạn.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 7,
#   'ingredients': ['Ghẹ 1 con',
#    'rau muống trắng 1 mớ',
#    'ngổ',
#    'muối',
#    'mì chính',
#    'tỏi',
#    'muối vừa đủ'],
#   'step': ['Bước 1: Ghẹ làm sạch, chặt làm 4 (bỏ đầu chân, đầu càng)',
#    'Bước 2: Phi thơm tỏi, cho ghẹ và gia vị vào xào lăn thật đều',
#    'Bước 3: Chế nước dùng vào đun sôi',
#    'Bước 4: Chờ ghẹ chín cho rau muống vào',
#    'Bước 5: Trước khi bóc ra cho thêm chút rau ngổ để dậy mùi thơm'],
#   'note': [],
#   'post_date': 'Thứ tư, 17/11/2021, 15:57 (GMT+7)'},
#  {'link': 'https://vnexpress.net/hai-mon-ngon-chua-benh-4311475.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Chè củ cải',
#   'description': 'Chè củ cải và rau cải xào nấm là hai món dễ làm lại lành tính, tăng cảm giác ngon miệng. Bạn hãy thử áp dụng công thức chế biến dưới đây nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 4,
#   'ingredients': ['Củ cải 300 g',
#    'gừng 1 miếng',
#    'mật ong 50 g',
#    'nước sạch 100 g'],
#   'step': ['Bước 1: Củ cải gọt vỏ, cắt miếng, gừng băm nhỏ. Dùng vải mỏng vắt lấy nước gừng, đun củ cải cùng với mật ong, nước sạch, nước gừng. Hầm nhỏ lửa đến khi củ cải nhừ là được',
#    'Bước 2: Công dụng: Thích hợp với những người bị ho, thở khò khè'],
#   'note': [],
#   'post_date': 'Thứ tư, 17/11/2021, 15:44 (GMT+7)'},
#  {'link': 'https://vnexpress.net/hai-mon-ngon-chua-benh-4311475.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Rau cải xào nấm',
#   'description': 'Chè củ cải và rau cải xào nấm là hai món dễ làm lại lành tính, tăng cảm giác ngon miệng. Bạn hãy thử áp dụng công thức chế biến dưới đây nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 4,
#   'ingredients': ['Nấm 150 g', 'rau cải 150 g', 'muối', 'dầu ăn vừa đủ'],
#   'step': ['Bước 1: Nấm rửa sạch, thái lát mỏng, rau cải rửa sạch. Cho dầu vào chảo, xào tái rau cải, cho muối và một chút nước vào đun sôi. Cho nấm vào đảo đều, đun sôi lên là được',
#    'Bước 2: Công dụng: Khai vị, tăng cảm giác ngon miệng'],
#   'note': [],
#   'post_date': 'Thứ tư, 17/11/2021, 15:44 (GMT+7)'},
#  {'link': 'https://vnexpress.net/bien-tau-mon-gan-4311449.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Gan ngỗng xốt dâu tây',
#   'description': 'Không chỉ đơn điệu là xào và rán, các loại gan như gà, vịt, bò, lợn, ngỗng còn có thể chế biến thành nhiều món ngon miệng lại đẹp mắt.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 9,
#   'ingredients': ['120 g gan ngỗng',
#    '10 ml dầu ôliu',
#    '100 g quả dâu tây',
#    '1 củ hành tây',
#    '1/2 bát nước dùng gà',
#    '1/4 quả chanh',
#    '2 thìa cà phê nước muối tiêu xay',
#    '1 cọng rau mùi tây',
#    '1 thìa cà phê kem sữa tươi'],
#   'step': ['Bước 1: Nhặt bỏ cuống dâu tây, rửa sạch, để ráo, thái hạt lựu. Đun nóng dầu, cho hành tây vào xào vàng thơm, cho tiếp dâu tây xào trên lửa nhỏ, cho nước dùng gà vào',
#    'Bước 2: Tiếp tục đun đến khi hỗn hợp dâu vừa mềm, nước sốt sánh đặc lại, nêm chút muối tiêu, cho nước cốt chanh vào. Ướp gan ngỗng với muối, tiêu vừa ăn. Đun nóng chút dầu khác, cho gan vào rán vàng trên lửa nhỏ, trở đều hai mặt',
#    'Bước 3: Lấy gan ra đĩa, rưới xốt dâu lên, trang trí kem sữa tươi và rau mùi tây, dùng nóng với bánh mì'],
#   'note': [],
#   'post_date': 'Thứ hai, 15/11/2021, 11:30 (GMT+7)'},
#  {'link': 'https://vnexpress.net/bien-tau-mon-gan-4311449.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Gan ngỗng xốt giấm đen',
#   'description': 'Không chỉ đơn điệu là xào và rán, các loại gan như gà, vịt, bò, lợn, ngỗng còn có thể chế biến thành nhiều món ngon miệng lại đẹp mắt.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 7,
#   'ingredients': ['120 g gan ngỗng',
#    '1 thìa cà phê dầu ôliu',
#    '80 ml giấm đen',
#    '20 ml giấm đỏ',
#    '1 tép tỏi',
#    '1 thìa cà phê muối',
#    'tiêu'],
#   'step': ['Bước 1: Tỏi lột vỏ, đập dập. Đun nóng nửa thìa cà phê dầu, cho tỏi vào xào vàng thơm. Cho tiếp giấm đen, đỏ, đường vào đun trên lửa nhỏ khoảng 15 phút, nêm muối',
#    'Bước 2: Ướp gan với muối, tiêu, để 5 phút cho ngấm đều. Đun nóng phần dầu còn lại, cho gan vào rán trên lửa nhỏ, trở đều hai mặt',
#    'Bước 3: Xếp gan ra đĩa, rưới xốt giấm lên, dùng nóng với bánh mì nướng giòn'],
#   'note': [],
#   'post_date': 'Thứ hai, 15/11/2021, 11:30 (GMT+7)'},
#  {'link': 'https://vnexpress.net/bien-tau-mon-gan-4311449.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Gan vịt rán vàng xốt chanh',
#   'description': 'Không chỉ đơn điệu là xào và rán, các loại gan như gà, vịt, bò, lợn, ngỗng còn có thể chế biến thành nhiều món ngon miệng lại đẹp mắt.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 10,
#   'ingredients': ['250 g gan vịt',
#    '1 thìa cà phê tỏi xay',
#    '3 quả chanh tươi',
#    '20 g hành tây',
#    '1 thìa súp đường',
#    '1 quả ớt sừng',
#    '1 thìa cà phê muối',
#    'tiêu',
#    '10 g bột mì',
#    '10 g bơ lạc'],
#   'step': ['Bước 1: Rửa gan vịt với nước muối, để ráo nước. Vắt hai quả chanh lấy nước cốt, 1 quả thái mỏng. Xay nhuyễn hành tây, vắt lấy nước',
#    'Bước 2: Đun nước cốt chanh, nước hành tây, đường, ớt sừng băm, muối tiêu trên lửa nhỏ. Cho bột mì pha nước vào để hỗn hợp sánh lại. Đun chảy bơ, phi thơm tỏi, cho gan vịt vào rán vàng',
#    'Bước 3: Xếp gan ra đĩa, trang trí chanh, rưới xốt chanh dùng nóng'],
#   'note': [],
#   'post_date': 'Thứ hai, 15/11/2021, 11:30 (GMT+7)'},
#  {'link': 'https://vnexpress.net/bien-tau-mon-gan-4311449.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Gan gà rán muối ớt',
#   'description': 'Không chỉ đơn điệu là xào và rán, các loại gan như gà, vịt, bò, lợn, ngỗng còn có thể chế biến thành nhiều món ngon miệng lại đẹp mắt.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 11,
#   'ingredients': ['200 g gan gà',
#    '1 củ hành tây',
#    '1 thìa súp muối hạt',
#    '2 quả ớt sừng',
#    '1 củ tỏi',
#    '1 cây hành lá',
#    '20 g bột mì',
#    '1 quả trứng gà',
#    '300 ml dầu ăn',
#    'muối',
#    'tiêu'],
#   'step': ['Bước 1: Rửa gan gà với nước muối, thái mùi hành tây, thái khúc hành lá. Thái mỏng tỏi và một quả ớt. Giã nhuyễn muối hạt với quả ớt còn lại, tỏi, trộn đều',
#    'Bước 2: Đun nóng dầu, nhúng gan vào trứng gà đã đánh tan lăn qua bột mì, cho vào chảo rán vàng, vớt ráo dầu. Đun nóng chảo, cho hành tây, tỏi, ớt gan hỗn hợp muối ớt vào đảo đều tay',
#    'Bước 3: Món này dùng với cơm trắng'],
#   'note': [],
#   'post_date': 'Thứ hai, 15/11/2021, 11:30 (GMT+7)'},
#  {'link': 'https://vnexpress.net/bien-tau-mon-gan-4311449.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Pa-tê gan lợn',
#   'description': 'Không chỉ đơn điệu là xào và rán, các loại gan như gà, vịt, bò, lợn, ngỗng còn có thể chế biến thành nhiều món ngon miệng lại đẹp mắt.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 9,
#   'ingredients': ['350 g gan lợn',
#    '100 ml sữa tươi',
#    '1 quả trứng gà',
#    '1 thìa cà phê bột nhục đậu khấu',
#    '1 thìa súp bột hành tây',
#    '30 ml rượu thơm',
#    '1 thìa cà phê muối',
#    'tiêu',
#    'dầu ăn'],
#   'step': ['Bước 1: Rửa gan lợn, thái nhỏ, ngâm với sữa tươi, cho vào tủ lạnh giữ khoảng 4 giờ. Lấy gan ra xay nhuyễn với trứng gà. Trộn đều gan với bột nhục đậu khấu, bột hành tây, rượu thơm, muối tiêu. Thêm chút dầu vào khuôn tròn, cho hỗn hợp gan vào, xếp trong khay có chút nước, đặt vào lò nướng ở nhiệt độ 150 độ C khoảng 30 phút',
#    'Bước 2: Dùng lạnh với trái cây, xà lách'],
#   'note': [],
#   'post_date': 'Thứ hai, 15/11/2021, 11:30 (GMT+7)'},
#  {'link': 'https://vnexpress.net/quen-la-voi-tom-4311462.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Tôm xốt coca cola',
#   'description': 'Tôm là món hải sản có vị ngọt tự nhiên rất được ưa chuộng. Bạn chỉ cần mươi phút là có thể chế biến xong ba món tôm rất ngon dưới đây.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 6,
#   'ingredients': ['3 con tôm càng',
#    '4 thìa súp coca cola',
#    '1 thìa cà phê tỏi băm',
#    '1/4 thìa cà phê tiêu',
#    '1 thìa cà phê hạt nêm',
#    '1 thìa súp dầu ăn'],
#   'step': ['Bước 1: Tôm lột vỏ, chừa đuôi, ướp với tỏi băm, hạt nêm, tiêu và hai thìa súp coca cola',
#    'Bước 2: Bắc chảo nóng cho dầu ăn vào phi tỏi cho thơm, cho tôm vào xào',
#    'Bước 3: Tôm chín cho thêm hai thìa súp coca cola vào, nấu sôi lại, tắt bếp'],
#   'note': [],
#   'post_date': 'Thứ hai, 15/11/2021, 11:25 (GMT+7)'},
#  {'link': 'https://vnexpress.net/quen-la-voi-tom-4311462.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Tôm trộn cải mầm dầu giấm',
#   'description': 'Tôm là món hải sản có vị ngọt tự nhiên rất được ưa chuộng. Bạn chỉ cần mươi phút là có thể chế biến xong ba món tôm rất ngon dưới đây.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 5,
#   'ingredients': ['2 con tôm càng',
#    '100 g cải nấm',
#    '1 chén nước dừa tươi',
#    '1/2 thìa cà phê hạt nêm',
#    'Dầu giấm: 1/3 chén giấm + 2 thìa cà phê đường + 1/2 thìa cà phê hạt nêm + 1/3 thìa cà phê tiêu + 1 thìa súp dầu ô-liu. Tất cả khuấy cho tan đều'],
#   'step': ['Bước 1: Tôm ướp với hạt nêm để khoảng 5 phút cho thấm',
#    'Bước 2: Bắc nước dừa lên, cho tôm vào luộc chín',
#    'Bước 3: Cải mầm rửa sạch, vẩy ráo, xếp ra đĩa, xếp tôm lên trên',
#    'Bước 4: Khi ăn rưới dầu giấm lên, trộn đều'],
#   'note': [],
#   'post_date': 'Thứ hai, 15/11/2021, 11:25 (GMT+7)'},
#  {'link': 'https://vnexpress.net/quen-la-voi-tom-4311462.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Canh chua tôm nõn',
#   'description': 'Tôm là món hải sản có vị ngọt tự nhiên rất được ưa chuộng. Bạn chỉ cần mươi phút là có thể chế biến xong ba món tôm rất ngon dưới đây.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 11,
#   'ingredients': ['200 g tôm nõn',
#    '200 g măng chua',
#    '1 trái cà chín',
#    '1 thìa cà phê tỏi băm',
#    '1/2 thìa cà phê hạt nêm',
#    '1/2 thìa cà phê đường',
#    '2 thìa cà phê nước mắm',
#    'rau om',
#    'ngò gai',
#    'ớt',
#    'dầu ăn'],
#   'step': ['Bước 1: Măng chua rửa sạch vắt ráo nước, cà chua xắt múi',
#    'Bước 2: Rau om, ngò gai xắt nhuyễn, ớt xắt lát',
#    'Bước 3: Bắc nồi nóng, cho dầu vào phi tỏi cho thơm',
#    'Bước 4: Vớt tỏi ra, dùng lại nồi đó cho cà chua vào xào sơ',
#    'Bước 5: Cho 2 chén nước, thêm măng vào nấu sôi vài phút cho măng ra nước chua',
#    'Bước 6: Nêm hạt nêm và đường rồi cho tôm vào nấu sôi bùng, thêm nước mắm cho vừa ăn rồi tắt bếp',
#    'Bước 7: Bày ra tô',
#    'Bước 8: Cho ngò gai, ngò om, ớt và tỏi phi lên mặt'],
#   'note': [],
#   'post_date': 'Thứ hai, 15/11/2021, 11:25 (GMT+7)'},
#  {'link': 'https://vnexpress.net/hai-mon-ngay-thuong-ngon-mieng-4311469.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Bí cuốn tôm thịt',
#   'description': 'Chỉ với vài miếng đậu hũ, một trái bí hay đơn giản chỉ là một tàu lá chuối mà mâm cơm của gia đình bạn sẽ thêm phần hấp dẫn. Bí quyết ở đây là sự khéo léo trong cách gia giảm và trình bày.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 10,
#   'ingredients': ['1 quả bí xanh',
#    '100 g tôm lột vỏ',
#    '50 g giò sống',
#    'tỏi',
#    'hành lá',
#    'ớt',
#    'muối',
#    'tiêu',
#    'đường',
#    'nước mắm'],
#   'step': ['Bước 1: Bí xanh chọn quả thẳng, còn non, hột ít',
#    'Bước 2: Gọt vỏ, dùng dao bào, bào bí thành từng lát mỏng',
#    'Bước 3: Tôm băm nhuyễn trộn chung với tỏi, giò sống, nêm muối, tiêu, đường',
#    'Bước 4: Trải miếng bí ra, trét nhân tôm lên rồi cuộn lại',
#    'Bước 5: Xếp vào đĩa rồi đem hấp chín, khoảng 5 phút',
#    'Bước 6: Dọn kèm nước mắm ớt',
#    'Bước 7: Ăn chung với cơm, vị nhẹ và thanh'],
#   'note': [],
#   'post_date': 'Thứ hai, 15/11/2021, 11:15 (GMT+7)'},
#  {'link': 'https://vnexpress.net/hai-mon-ngay-thuong-ngon-mieng-4311469.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Đậu hũ nhồi tôm sốt chua cay',
#   'description': 'Chỉ với vài miếng đậu hũ, một trái bí hay đơn giản chỉ là một tàu lá chuối mà mâm cơm của gia đình bạn sẽ thêm phần hấp dẫn. Bí quyết ở đây là sự khéo léo trong cách gia giảm và trình bày.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 12,
#   'ingredients': ['2 miếng đậu hũ',
#    '100 g tôm tươi',
#    '1 quả cà chua',
#    'tỏi',
#    'băm',
#    'ớt',
#    'nước mắm',
#    'muối',
#    'dấm',
#    'đường',
#    'dầu ăn',
#    'bột bắp'],
#   'step': ['Bước 1: Đậu hũ cắt miếng chữ nhật 2x3cm, dùng dao khoét một lỗ ổ chính giữa miếng đậu. Tôm bóc vỏ dùng dao đập dập rồi mới băm nhỏ. Trộn tôm với tỏi, muối, tiêu, đường. Cho nhân vào chỗ khoét miếng đậu, lăn qua bột năng chiên chín vàng, xếp ra đĩa',
#    'Bước 2: Cà chua băm nhỏ. Xào tỏi cho thơm, cho cà chua vào xào chín, nêm ước mắm, đường, muối, giấm, vừa ăn, cho thêm chút bột bắp pha loãng để sauce có độ sánh vừa phải. Chan sauce lên đĩa đậu dùng nóng'],
#   'note': [],
#   'post_date': 'Thứ hai, 15/11/2021, 11:15 (GMT+7)'},
#  {'link': 'https://vnexpress.net/hai-mon-ngon-mang-vi-ngot-cam-thao-4311314.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Giò lợn hầm',
#   'description': 'Bề ngoài khô cứng, xù xì, chẳng có gì đẹp mắt, nhưng cam thảo lại có vị ngọt nhẹ, thanh nhưng thấm sâu vào tận cuống lưỡi. Dưới đây là 2 món ăn được chế biến cùng cam thảo đem lại hiệu quả tốt cho sức khỏe.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 12,
#   'ingredients': ['600 g giò lợn',
#    '4 g cam thảo',
#    '20 g đương quy',
#    '15 g bá kích',
#    '8 g thương truật',
#    '8 g can khương',
#    '1 khúc gừng',
#    'đường',
#    'muối',
#    'hành lá',
#    'tiêu',
#    'dầu ăn'],
#   'step': ['Bước 1: Rửa sạch các loại thảo mộc, cho vào nồi nấu với 3 tô nước, để lửa vừa, nấu còn khoảng 1/2 lượng nước. Giò lợn cạo hết lông, rửa sạch, rút xương, dùng chỉ bó tròn lại. Gừng thái sợi hay thái lát. Hành lá tước sợi, đầu hành đập giập',
#    'Bước 2: Đun nóng khoảng 1/2 thìa súp dầu ăn, cho gừng, đầu hành vào xào thơm. Cho giò lợn vào đảo đều cho săn lại. Thêm nước hầm thảo dược vào. Nêm 1/2 thìa cà phê muối, 2 thìa cà phê đường sao cho vừa miệng rồi nấu đến khi giò lợn chín vừa ăn',
#    'Bước 3: Lấy giò lợn ra, rút bỏ chỉ, thái khoanh tròn, cho vào tô hoặc bát. Thêm nước hầm, hành lá, tiêu. Dùng nóng',
#    'Bước 4: Mẹo nhỏ: Chọn giò trước, ít mỡ để tránh gây ngán. Trong khi nấu, nên vớt lượng mỡ thừa tiết ra từ giò lợn để nước trong, thanh hơn'],
#   'note': [],
#   'post_date': 'Thứ năm, 11/11/2021, 16:34 (GMT+7)'},
#  {'link': 'https://vnexpress.net/hai-mon-ngon-mang-vi-ngot-cam-thao-4311314.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Chè đậu cam thảo',
#   'description': 'Bề ngoài khô cứng, xù xì, chẳng có gì đẹp mắt, nhưng cam thảo lại có vị ngọt nhẹ, thanh nhưng thấm sâu vào tận cuống lưỡi. Dưới đây là 2 món ăn được chế biến cùng cam thảo đem lại hiệu quả tốt cho sức khỏe.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 6,
#   'ingredients': ['100 đậu đen',
#    '100 g đậu đỏ',
#    '100 g đậu xanh',
#    '6 g cam thảo',
#    '150 g đường',
#    'muối'],
#   'step': ['Bước 1: Rửa sạch các loại đậu. Nếu có thời gian, bạn nên ngâm qua đêm cho đậu nở mềm. Cam thảo rửa sạch, chặt thành khúc ngắn hay lát xéo. Đun sôi khoảng 1 lít nước, cho đậu vào nấu đến khi vừa chín, cho lửa liu riu, tránh sôi bùng',
#    'Bước 2: Khi đậu vừa chín tới, cho cam thảo, đường, 1/2 thìa cà phê muối vào nấu đến khi đậu nở mềm, vừa ăn. Thêm nước nếu chè quá đặc',
#    'Bước 3: Chè này có thể dùng nóng hoặc thêm đá, tùy thích. Đây là món có tác dụng giải nhiệt khi tiết trời nắng nóng',
#    'Bước 4: Mẹo nhỏ: Chè không được quá đặc cũng không nên quá loãng. Nêm đường vừa phải, không gắt để cảm nhận được vị thanh và ngọt nhẹ của cam thảo'],
#   'note': [],
#   'post_date': 'Thứ năm, 11/11/2021, 16:34 (GMT+7)'},
#  {'link': 'https://vnexpress.net/nhung-mon-ngon-dam-da-vi-moi-4311459.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Gà nướng lá chanh',
#   'description': 'Với ba món nướng, hầm và salad, bạn đã có đủ hương vị phong phú cho bữa cơm gia đình. Cuối bữa tráng miệng với món chuối rim mật nước cốt dừa đơn giản nhưng cũng rất ngon.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 17,
#   'ingredients': ['300 g thịt gà nạc',
#    '100 g mỡ lợn',
#    '100 g nấm kim châm',
#    '1 thìa cà phê tỏi băm',
#    '1 thìa cà phê sả băm',
#    '1 củ hành trắng',
#    '1 trái chanh',
#    '1/4 gói ngũ vị hương',
#    '1 thìa cà phê màu điều',
#    'mỡ hành',
#    'hành phi',
#    'tiêu',
#    'đường',
#    'ngò',
#    'ớt',
#    'nước tương',
#    'vài lá chanh'],
#   'step': ['Bước 1: Mỡ lợn luộc chín xắt lát mỏng. Ướp mỡ lợn với đường và chút muối cho mỡ có độ trong. Thịt gà rửa sạch xắt miếng mỏng lớn, lá chanh xắt sợi thật nhuyễn. Nấm kim châm cắt khúc. Ướp thịt gà với tỏi băm, sả băm, hành phi, đường, nước tương, ngũ vị hương trộn đều',
#    'Bước 2: Vắt một miếng chanh vào, trải lá chanh ra, xếp một miếng mỡ, vài nhánh nấm kim châm, cuối cùng là một miếng gà. Gấp lá chanh lại xiên vào que. Xếp các cuốn gà vào vỉ nướng, thoa một lớp màu điều trên mặt thịt gà, nướng 10 phút với nhiệt độ 250 độ C'],
#   'note': [],
#   'post_date': 'Thứ năm, 11/11/2021, 16:25 (GMT+7)'},
#  {'link': 'https://vnexpress.net/nhung-mon-ngon-dam-da-vi-moi-4311459.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Salad trứng cua',
#   'description': 'Với ba món nướng, hầm và salad, bạn đã có đủ hương vị phong phú cho bữa cơm gia đình. Cuối bữa tráng miệng với món chuối rim mật nước cốt dừa đơn giản nhưng cũng rất ngon.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 13,
#   'ingredients': ['2 cây xà lách dún',
#    '2 quả trứng gà',
#    '100 g thịt cua',
#    '1 lọn bún tàu',
#    '1 tai nấm mèo',
#    '1 thìa cà phê hạt nêm',
#    '1 thìa súp đường',
#    '1/4 thìa cà phê tiêu',
#    '1 thìa súp nước mắm ngon',
#    '1 thìa cà phê ớt băm',
#    '1 thìa súp nước cốt chanh',
#    '1 trái ớt tươi',
#    'hành lá'],
#   'step': ['Bước 1: Xà lách nhặt rửa sạch. Bún tàu, nấm mèo, ngâm nở xắt nhỏ. Hành lá xắt khúc ngắn. Thịt cua vắt cho ráo nước, xé nhỏ, trộn tiêu, hạt nêm, ớt băm nhỏ. Pha nước mắm với nước cốt chanh, đường và ớt băm cho sệt. Bắc bếp, phi thơm đầu hành trắng. Cho cua vào xào thơm, trộn bún tàu và nấm mèo sau đó cho trứng vào đánh đều, nêm thêm hạt nêm, tiêu. Đặt nồi hấp lên bếp, cho hỗn hợp trứng',
#    'Bước 2: cua vào, hấp chín, lấy ra, xắt miếng nhỏ'],
#   'note': [],
#   'post_date': 'Thứ năm, 11/11/2021, 16:25 (GMT+7)'},
#  {'link': 'https://vnexpress.net/nhung-mon-ngon-dam-da-vi-moi-4311459.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Canh củ cải hầm xương',
#   'description': 'Với ba món nướng, hầm và salad, bạn đã có đủ hương vị phong phú cho bữa cơm gia đình. Cuối bữa tráng miệng với món chuối rim mật nước cốt dừa đơn giản nhưng cũng rất ngon.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 10,
#   'ingredients': ['300 xương đùi',
#    '2 củ cải trắng',
#    '1 củ cà rốt',
#    '1 thìa cà phê hạt nêm',
#    'muối',
#    'tiêu',
#    'đường',
#    'hành lá',
#    'ngò rí',
#    'hành tím'],
#   'step': ['Bước 1: Củ cải trắng ngọt sạch vỏ, cắt khúc lớn',
#    'Bước 2: Cà rốt ngọt vỏ, tỉa hoa, xắt khoanh',
#    'Bước 3: Hành tím rửa sạch, nướng vàng thơm.Hành lá ngò rí nhặt rửa sạch, xắt nhuyễn',
#    'Bước 4: Đặt nồi nước lên bếp',
#    'Bước 5: Nước sôi cho củ hành tím và xương vào hầm lửa nhỏ',
#    'Bước 6: Nêm hạt nêm, muối đường vừa ăn, cho củ cải trắng và cà rốt vào hầm cho cả hai thứ vừa chín mềm',
#    'Bước 7: Cho hành lá, ngò rí vào nồi',
#    'Bước 8: Tắt bếp, nhắc xuống',
#    'Bước 9: Múc canh ra tô, dọn dùng nóng'],
#   'note': [],
#   'post_date': 'Thứ năm, 11/11/2021, 16:25 (GMT+7)'},
#  {'link': 'https://vnexpress.net/nhung-mon-ngon-dam-da-vi-moi-4311459.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Chuối rim mật nước cốt dừa',
#   'description': 'Với ba món nướng, hầm và salad, bạn đã có đủ hương vị phong phú cho bữa cơm gia đình. Cuối bữa tráng miệng với món chuối rim mật nước cốt dừa đơn giản nhưng cũng rất ngon.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 5,
#   'ingredients': ['trái chuối sứ',
#    '100g đường mật',
#    '20g mè trắng',
#    '100g dừa nạo',
#    'muối'],
#   'step': ['Bước 1: Chuối sứ chọn trái vừa chín tới, còn cứng, bóc vỏ cho đường vào trộn đều, ướp chuối với đường khoảng 3 giờ',
#    'Bước 2: Mè trắng rang vàng, dừa vắt lấy khoảng 1 chén nước cốt',
#    'Bước 3: Đặt chảo lên bếp, cho chuối vào đảo với lửa thật nhỏ',
#    'Bước 4: Khi đường cạn và chuối chuyển sang màu đỏ, vớt ra để nguội xắt khoanh',
#    'Bước 5: Đặt nước cốt dừa lên bếp, nấu sôi nêm chút muối và đường',
#    'Bước 6: Cho chuối vào nước cốt dừa, trộn đều',
#    'Bước 7: Khi ăn rắc thêm mè rang'],
#   'note': [],
#   'post_date': 'Thứ năm, 11/11/2021, 16:25 (GMT+7)'},
#  {'link': 'https://vnexpress.net/mon-ngon-voi-ca-chua-4311445.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Cà bi kho cá bống trứng',
#   'description': 'Từ cà chua nhồi đến xào hay làm sốt... đều góp phần làm cho bữa ăn thêm đa dạng và phong phú. Ba món ngon, lạ miệng chế biến cùng cà chua dưới đây có thể là gợi ý hay cho bạn.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 9,
#   'ingredients': ['300 g cá bống trứng',
#    '100 g cà chua bi. 1/2 chén nước mắm ngon',
#    '2 thìa cà phê đường cát vàng',
#    '1 thìa súp mỡ nước',
#    'tiêu',
#    'hành tím',
#    'hành lá',
#    'tỏi',
#    'ớt'],
#   'step': ['Bước 1: Cá bống trứng mua về lấy nước muối rửa sạch, để ra rổ cho ráo nước. Cà chua bi bỏ cuống rửa kỹ',
#    'Bước 2: Bắc nồi mỡ nóng, mỡ sôi tăm cho tỏi, hành tím, hành lá xắt nhuyễn vào. Hành tỏi vàng thơm cho nước mắm, đường. Nước mắm sôi trút cá vào. Cá cong cứng mình thì bỏ tiếp cà chua bi, nêm thêm tiêu, chừng 3 phút nhắc xuống',
#    'Bước 3: Dùng kèm cơm nóng và ớt hiểm'],
#   'note': [],
#   'post_date': 'Thứ năm, 11/11/2021, 16:11 (GMT+7)'},
#  {'link': 'https://vnexpress.net/mon-ngon-voi-ca-chua-4311445.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Cà chua nhồi óc lợn',
#   'description': 'Từ cà chua nhồi đến xào hay làm sốt... đều góp phần làm cho bữa ăn thêm đa dạng và phong phú. Ba món ngon, lạ miệng chế biến cùng cà chua dưới đây có thể là gợi ý hay cho bạn.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 11,
#   'ingredients': ['1 bộ óc lợn',
#    '50 g bột mì',
#    '1 trái trứng gà',
#    '4 trái cà chua',
#    '2 thìa càphê hạt nêm',
#    'tiêu',
#    'đường',
#    'hành tím',
#    'hành lá',
#    'tỏi',
#    'dầu để chiên'],
#   'step': ['Bước 1: Óc lợn mua về rửa sạch, để ráo. Cà chua cắt đôi, bỏ hết hạt và ruột bên trong. Trứng gà đánh nổi, cho bột mì vào khuấy đều',
#    'Bước 2: Tán nhuyễn óc lợn rồi trộn chung với hỗn hợp bột mì và trứng. Nêm hạt nêm, tiêu, đường và tỏi băm, hành tím, hành lá xắt nhuyễn',
#    'Bước 3: Nhồi hỗn hợp óc lợn đã nêm nếm vừa ăn vào cà chua. Đem chiên trong chảo dầu ăn với lửa riu riu, thấy mặt óc lợn vàng rộm là vớt ra',
#    'Bước 4: Món này dùng kèm tương ớt hoặc tương cà'],
#   'note': [],
#   'post_date': 'Thứ năm, 11/11/2021, 16:11 (GMT+7)'},
#  {'link': 'https://vnexpress.net/mon-ngon-voi-ca-chua-4311445.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Bắp chiên phô mai xốt cà chua',
#   'description': 'Từ cà chua nhồi đến xào hay làm sốt... đều góp phần làm cho bữa ăn thêm đa dạng và phong phú. Ba món ngon, lạ miệng chế biến cùng cà chua dưới đây có thể là gợi ý hay cho bạn.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 11,
#   'ingredients': ['200 g bắp hạt',
#    '100 g phô mai',
#    '50 g bột mì. 1 trái trứng gà',
#    '1 trái cà chua',
#    '2 thìa càphê hạt nêm',
#    'Muối',
#    'tiêu',
#    'hành trắng',
#    'hành lá',
#    'tỏi',
#    'dầu ăn'],
#   'step': ['Bước 1: Bắp hạt rửa sạch để ráo. Tán phô mai cho nhuyễn mịn, trộn chung với bột mì, trứng gà, bắp. Nêm hạt nêm và muối tiêu, hành lá, tỏi băm cho vừa miệng',
#    'Bước 2: Bắc chảo dầu nóng, dùng thìa vê từng miếng bắp vừa ăn, cho vào chảo chiên lửa riu riu, bắp vàng đều vớt ra',
#    'Bước 3: Cà chua băm nhuyễn. Phi hành tỏi, hành trắng thơm vàng, cho cà chua vô lắc chảo, cà chua sền sệt lại là nhắc xuống rưới lên bắp, phô mai chiên. Dùng nóng giòn'],
#   'note': [],
#   'post_date': 'Thứ năm, 11/11/2021, 16:11 (GMT+7)'},
#  {'link': 'https://vnexpress.net/mon-ngon-la-mieng-4311432.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Tôm càng cá ngừ cuộn rong biển',
#   'description': 'Tôm càng cá ngừ cuộn rong biển, chả giò mực... sẽ giúp gia đình bạn đổi món. Bạn thử trổ tài sau khi tham khảo các công thức sau đây nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 15,
#   'ingredients': ['1 con tôm càng',
#    '60 g cá ngừ',
#    '1/2 lá rong biển khô',
#    '1 củ khoai tây',
#    '1 cây măng tây tươi',
#    '1/2 thìa cà phê hạt nêm',
#    '1 thìa súp miso hỗn hợp',
#    'nước tương Nhật',
#    'đường',
#    'tiêu',
#    'hành tây',
#    'hành lá',
#    'tỏi và gừng bằm',
#    'khoai tây hấp',
#    'rau xà lách'],
#   'step': ['Bước 1: Măng tây luộc chín vừa tới. Tôm càng luộc chín tới, lột vỏ, dùng hành lá cột chung với măng tây. Ngắt đầu tôm để trang trí, cá ngừ phi',
#    'Bước 2: lê ướp hạt nêm cho thấm. Trải rong biển ra rồi đặt cá ngừ lên, cuốn tròn, đem nướng vừa chín',
#    'Bước 3: Bắc chảo nóng, cho hành tây, tỏi và gừng bằm vào chảo cho vừa vàng không khét. Cho hỗn hợp vào xào nhanh tay, sau đó cho nước tương vào, nêm đường và tiêu cho vừa ăn. Chú ý, không nêm muối vì sốt đã mặn sẵn. Dùng chung với khoai tây hấp và rau xà lách'],
#   'note': [],
#   'post_date': 'Thứ năm, 11/11/2021, 16:06 (GMT+7)'},
#  {'link': 'https://vnexpress.net/mon-ngon-la-mieng-4311432.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Chả giò mực',
#   'description': 'Tôm càng cá ngừ cuộn rong biển, chả giò mực... sẽ giúp gia đình bạn đổi món. Bạn thử trổ tài sau khi tham khảo các công thức sau đây nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 9,
#   'ingredients': ['1 kg mực nang',
#    '200 g mỡ xay',
#    '1 xấp bánh tráng',
#    '50 g đường',
#    '1 thìa cà phê tiêu',
#    '1 thìa cà phê bột ngọt',
#    'đầu hành',
#    'hành tím xay',
#    'dầu để chiên'],
#   'step': ['Bước 1: Mực nang làm sạch, lau khô, xay nhuyễn',
#    'Bước 2: Trộn mực nang đã xay với mỡ heo và đầu hành, ướp bột ngọt, đường, tiêu cho thấm gia vị',
#    'Bước 3: Trải bánh tráng ra, cho hỗn hợp trên vào, cuốn lại thành chả giò',
#    'Bước 4: Bắc chảo dầu nóng, cho chả giò vào chiên vàng đều 2 mặt, vớt ra để ráo',
#    'Bước 5: Dọn ăn với nước mắm me và xà lách, rau thơm'],
#   'note': [],
#   'post_date': 'Thứ năm, 11/11/2021, 16:06 (GMT+7)'},
#  {'link': 'https://vnexpress.net/bua-com-dam-mau-sac-4311435.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Cải thìa xốt bắp Mỹ',
#   'description': 'Những món ăn dưới đây đều phong phú từ màu sắc, nguyên liệu đến cách chế biến nên rất hấp dẫn và ngon miệng. Bạn thử tham khảo và trổ tài nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 10,
#   'ingredients': ['500 g cải thìa',
#    '1/2 chén bắp Mỹ luộc',
#    '1 thìa súp cà rốt xắt hạt lựu',
#    '1 thìa súp củ cái trắng xắt hạt lựu',
#    '1 thìa súp ớt chuông xắt hạt lựu',
#    '1 tai nấm mèo xắt hạt lựu',
#    '1 chén nước dùng',
#    '1 thìa cà phê tỏi băm',
#    '1/4 thìa cà phê tiêu',
#    '2 thìa cà phê hạt nêm'],
#   'step': ['Bước 1: Nấu sôi một ít nước, thêm 1 thìa cà phê hạt nêm và 1 thìa cà phê dầu ăn, cho cải thìa vào trụng chín, vớt để ráo. Phi thơm tỏi băm, cho cà rốt, nấm mèo, củ cải trắng, bắp và ớt chuông vào xào. Nêm 1/2 thìa cà phê hạt nêm, cho nước dùng vào nấu. Cho nước bột bắp vào từ từ cho có độ sánh là được',
#    'Bước 2: Xếp cải vào đĩa chế nước xốt lên'],
#   'note': [],
#   'post_date': 'Thứ năm, 11/11/2021, 16:03 (GMT+7)'},
#  {'link': 'https://vnexpress.net/bua-com-dam-mau-sac-4311435.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Mực hấp xốt cay',
#   'description': 'Những món ăn dưới đây đều phong phú từ màu sắc, nguyên liệu đến cách chế biến nên rất hấp dẫn và ngon miệng. Bạn thử tham khảo và trổ tài nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 12,
#   'ingredients': ['4 con mực ống',
#    '1 củ hành tây',
#    '2 lát gừng',
#    '1 thìa cà phê ớt băm',
#    '1 thìa cà phê tỏi băm',
#    '1/2 thìa cà phê tiêu xay',
#    '1 thìa cà phê dầu hào',
#    '1 thìa cà phê nước tương',
#    'dầu ăn',
#    'bột bắp pha nước',
#    'hành',
#    'ngò trang trí'],
#   'step': ['Bước 1: Mực ống làm sạch khứa nhẹ mặt',
#    'Bước 2: Hành tây xắt múi nhỏ',
#    'Bước 3: Gừng đập dập',
#    'Bước 4: Cho gừng vào nước đun sôi, trụng mực khoảng 2 phút cho chín',
#    'Bước 5: Bắc chảo dầu, xào thơm hành tây rồi cho ra đĩa, xếp mực lên trên',
#    'Bước 6: Phi thơm tỏi băm, cho 1/2 chén nước vào nấu sôi',
#    'Bước 7: Cho ớt băm, tiêu, dầu hào, nước tương vào nêm vừa ăn',
#    'Bước 8: Cho nước bột bắp vào từ từ để tạo độ sánh, rưới xốt mực lên'],
#   'note': [],
#   'post_date': 'Thứ năm, 11/11/2021, 16:03 (GMT+7)'},
#  {'link': 'https://vnexpress.net/bua-com-dam-mau-sac-4311435.html',
#   'type_of_food': 'Món ngon hàng ngày',
#   'title': 'Cải thảo xào khô',
#   'description': 'Những món ăn dưới đây đều phong phú từ màu sắc, nguyên liệu đến cách chế biến nên rất hấp dẫn và ngon miệng. Bạn thử tham khảo và trổ tài nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 9,
#   'ingredients': ['200 g cải thảo',
#    '50 g tôm khô',
#    '1/2 củ cà rốt',
#    '1/2 trái ớt chuông xanh',
#    '1 trái ớt sừng',
#    '1 thìa cà phê hành tỏi băm',
#    '1 thìa cà phê hạt nêm',
#    '1/4 thìa cà phê tiêu',
#    '1 thìa súp dầu ăn'],
#   'step': ['Bước 1: Hành lá, ớt tỉa hoa, ngò trang trí',
#    'Bước 2: Tôm khô ngâm khoảng 10 phút, để ráo',
#    'Bước 3: Cải thảo nhặt rửa sạch, xắt sợi dài 10 cm',
#    'Bước 4: Cà rốt, ớt chuông xanh xắt sợi',
# ...
#    'Bước 2: Nước xốt trộn gỏi: nước mắm khuấy tan đều với đường, nước cốt chanh, cho tỏi và ớt băm vào sau cùng',
#    'Bước 3: Trộn rau củ, trái cây, rưới nước xốt trộn gỏi vào cho đều. Cho tôm khô lên mặt, rắc mè rang và hành phi',
#    'Bước 4: Gỏi mãng cầu ăn với bánh phồng tôm và nước mắm chua ngọt'],
#   'note': [],
#   'post_date': 'Thứ hai, 25/10/2021, 16:39 (GMT+7)'},
#  {'link': 'https://vnexpress.net/mon-man-tu-hoa-qua-4311321.html',
#   'type_of_food': 'Món ngon cho cuối tuần',
#   'title': 'Lẩu hoa quả',
#   'description': 'Thử biến tấu một chút, bạn sẽ ngạc nhiên bởi mùi thơm và vị mát từ các loại quả sẽ làm cho các món ăn hấp dẫn và mới lạ hơn nhiều.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 13,
#   'ingredients': ['Tôm sú: 200 g',
#    'mực: 200 g',
#    'phi lê cá mú: 200 g',
#    'xương ống heo: 1/2 kg',
#    'lê: 1 quả',
#    'thanh long: 1 quả',
#    'kiwi: 2 quả',
#    'dâu tây: 8 quả',
#    'củ năng: 100 g',
#    'táo đỏ: 50 g',
#    'tuyết nhĩ: 50 g',
#    'muối: 1 thìa cà phê',
#    'đường: 1 thìa cà phê'],
#   'step': ['Bước 1: Xương heo nấu với củ năng, táo đỏ lấy nước dùng, nêm muối, đường. Tôm, mực, cá, cắt miếng xếp ra đĩa. Các loại quả cắt miếng, xếp ra đĩa. Tuyết nhĩ ngâm nở cho vào nồi nước lẩu. Lẩu nấu sôi cho các thứ quả vào, sau đó cho tôm, cá, mực vào',
#    'Bước 2: Lẩu hoa quả ăn với rau và bún gạo, nước tương'],
#   'note': [],
#   'post_date': 'Thứ hai, 25/10/2021, 16:39 (GMT+7)'},
#  {'link': 'https://vnexpress.net/mon-man-tu-hoa-qua-4311321.html',
#   'type_of_food': 'Món ngon cho cuối tuần',
#   'title': 'Chả giò hoa quả',
#   'description': 'Thử biến tấu một chút, bạn sẽ ngạc nhiên bởi mùi thơm và vị mát từ các loại quả sẽ làm cho các món ăn hấp dẫn và mới lạ hơn nhiều.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 14,
#   'ingredients': ['Tôm sú: 200 g',
#    'lê: 1/2 quả',
#    'táo: 1/2 quả',
#    'kiwi: 1 quả',
#    'dâu: 4 quả',
#    'xoài: 1/2 quả',
#    'dứa: 1 miếng; muối: 1/2 thìa cà phê',
#    'đường: 1 thìa cà phê',
#    'tiêu: 1/4 thìa cà phê',
#    'bột nêm: 1/2 thìa cà phê',
#    'xốt mayonnaise: 1 thìa soup',
#    'bánh tráng pía: 6 cái',
#    'trứng gà: 2 quả',
#    'bột xù: 1 chén'],
#   'step': ['Bước 1: Tôm sú luộc chín cắt hạt lựu. Các loại quả cắt hạt lựu. Trộn quả, tôm, xốt mayonnaise và gia vị đều nhau. Dùng bánh tráng cho nhân đã trộn vào, nhúng trứng gà, lăn qua bột xù. Rán chả giò ngập dầu, thấy vừa vàng là được',
#    'Bước 2: Dọn ra đĩa trang trí thêm rau cho bắt mắt'],
#   'note': [],
#   'post_date': 'Thứ hai, 25/10/2021, 16:39 (GMT+7)'},
#  {'link': 'https://vnexpress.net/la-mieng-voi-nam-4311438.html',
#   'type_of_food': 'Món ngon cho cuối tuần',
#   'title': 'Salad nấm kim châm',
#   'description': 'Vừa ngon lại dễ chế biến, các món ăn làm từ nấm sẽ đem đến cho gia đình bạn một cảm giác mới lạ. Bạn thử trổ tài qua những gợi ý dưới đây nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 6,
#   'ingredients': ['Dưa chuột',
#    'cà rốt',
#    'nấm kim châm',
#    'thịt thăn',
#    'rau mùi',
#    'nước salad'],
#   'step': ['Bước 1: Thịt thăn luộc chín, thái chỉ',
#    'Bước 2: Dưa chuột, cà rốt, thái chỉ trộn lẫn nước salad pha sẵn',
#    'Bước 3: Bóp nhẹ, đều tay sao cho nước salad ngấm đều vào dưa chuột, cà rốt',
#    'Bước 4: Cho thêm nấm kim trâm đã được chần qua nước sôi rồi trộn đều',
#    'Bước 5: Rắc rau mùi, thịt thăn thái chỉ lên trên'],
#   'note': [],
#   'post_date': 'Thứ tư, 13/10/2021, 15:13 (GMT+7)'},
#  {'link': 'https://vnexpress.net/la-mieng-voi-nam-4311438.html',
#   'type_of_food': 'Món ngon cho cuối tuần',
#   'title': 'Cơm rang nấm canba',
#   'description': 'Vừa ngon lại dễ chế biến, các món ăn làm từ nấm sẽ đem đến cho gia đình bạn một cảm giác mới lạ. Bạn thử trổ tài qua những gợi ý dưới đây nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 6,
#   'ingredients': ['Cơm tám',
#    'nấm canba',
#    'ớt xanh',
#    'thịt lợn hun khói',
#    'trứng gà',
#    'gia vị'],
#   'step': ['Bước 1: Nấm canba nhặt kỹ, rửa sạch, trứng đánh đều và đảo qua mỡ',
#    'Bước 2: Đảo nấm canba và ớt xanh qua mỡ xôi đến khi có mùi thơm của nấm và ớt thì lấy ra trộn đều với trứng gà',
#    'Bước 3: Thịt lợn hun khói thái nhỏ, đảo qua chảo mỡ sôi đến khi có mùi thơm thì cho cơm vào đảo đều',
#    'Bước 4: Tiếp theo cho nấm canba, ớt, trứng gà vào đảo cùng với cơm và thịt đến khi cơm có mùi thơm hấp dẫn là được'],
#   'note': [],
#   'post_date': 'Thứ tư, 13/10/2021, 15:13 (GMT+7)'},
#  {'link': 'https://vnexpress.net/la-mieng-voi-nam-4311438.html',
#   'type_of_food': 'Món ngon cho cuối tuần',
#   'title': 'Lẩu nấm bụng dê',
#   'description': 'Vừa ngon lại dễ chế biến, các món ăn làm từ nấm sẽ đem đến cho gia đình bạn một cảm giác mới lạ. Bạn thử trổ tài qua những gợi ý dưới đây nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 23,
#   'ingredients': ['Nấm bụng dê 0',
#    '5 kg',
#    'xương lợn 1 kg',
#    'sườn lợn 0',
#    '5 kg',
#    'đậu hũ 4 miếng',
#    '100 g thịt nạc',
#    '100 g tôm',
#    'nấm đông cô',
#    'nấm rơm',
#    'nấm mỡ',
#    'nấm kim trâm',
#    'nấm bào ngư mỗi thứ 100 g',
#    'táo tàu 5 quả',
#    'sâm tươi 5 nhánh',
#    'kỳ tử 30 g',
#    'bún 0',
#    '5 kg',
#    'cà rốt nửa củ',
#    'củ cải nửa củ',
#    'bột nêm',
#    'nước mắm',
#    'muối'],
#   'step': ['Bước 1: Rửa sạch xương và sườn lợn rồi hầm nhỏ lửa với 1,5 lít nước trong khoảng 20 phút',
#    'Bước 2: Cho cà rốt, củ cải cắt lát, táo tau, kỳ tử, sâm vào',
#    'Bước 3: Nêm nửa thìa muối, 1 thìa nước mắm, 1 thìa cà phê bột nêm rồi đun thêm 15 phút',
#    'Bước 4: Thịt lợn rửa sạch, thái lát mỏng, đậu hũ thái miếng vuông',
#    'Bước 5: Rửa tôm, nấm, đậu hũ, xếp ra đĩa',
#    'Bước 6: Khi ăn, cho các nguyên liệu vào nồi lẩu'],
#   'note': [],
#   'post_date': 'Thứ tư, 13/10/2021, 15:13 (GMT+7)'},
#  {'link': 'https://vnexpress.net/cay-cay-mon-oc-4311274.html',
#   'type_of_food': 'Món ngon cho cuối tuần',
#   'title': 'Ốc móng tay trộn chua cay',
#   'description': 'Nấu các món ốc, phải có chút cay cay từ sả, ớt mới ngon. Xét ở góc độ ẩm thực, đó là sự quân bình âm dương nhưng với người thưởng thức, có tí xuýt xoa, hít hà thì càng thêm đã miệng.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 12,
#   'ingredients': ['1/2 kg ốc móng tay',
#    '2 cây sả',
#    '50 g rau húng lủi',
#    '2 trái ớt sừng',
#    '4 củ hành tím',
#    '1 củ tỏi',
#    '1 ít gừng giã giập',
#    '2 thìa súp tương ớt',
#    '1 thìa súp đường',
#    '1 thìa súp nước cốt chanh',
#    '1 thìa súp nước mắm',
#    '1 thìa cà phê hạt nêm'],
#   'step': ['Bước 1: Ốc rửa sạch. Rau húng lủi nhặt lấy lá, rửa sạch. Ớt, hành tím, tỏi xắt lát mỏng. Bắc nồi nước lên bếp, nấu thật sôi, cho vào ít gừng giã giập',
#    'Bước 2: Trụng ốc thật nhanh, vớt ra, tách một bên vỏ, chừa lại phần vỏ gắn với nạc ốc, để ráo. Trộn đều hành, ớt, tỏi xắt lát với tương ớt, nước mắm, đường, hạt nêm và nước cốt chanh làm nước trộn. Cho ốc đã luộc vào thố, rưới nước trộn, cho thêm rau húng lủi vào, trộn đều, gắp ra đĩa',
#    'Bước 3: Mách nhỏ: Ốc móng tay phải chọn ốc sống, tức những con bạn thấy còn ngọ nguậy. Khi trụng ốc phải đợi nước thật sôi, vừa cho vào là vớt ra ngay'],
#   'note': [],
#   'post_date': 'Thứ hai, 4/10/2021, 11:35 (GMT+7)'},
#  {'link': 'https://vnexpress.net/cay-cay-mon-oc-4311274.html',
#   'type_of_food': 'Món ngon cho cuối tuần',
#   'title': 'Ốc đỏ nấu sữa',
#   'description': 'Nấu các món ốc, phải có chút cay cay từ sả, ớt mới ngon. Xét ở góc độ ẩm thực, đó là sự quân bình âm dương nhưng với người thưởng thức, có tí xuýt xoa, hít hà thì càng thêm đã miệng.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 9,
#   'ingredients': ['1/2 kg ốc đỏ',
#    '2 cây sả',
#    '300 ml sữa tươi',
#    '1 thìa súp bơ',
#    '1 thìa cà phê hạt nêm',
#    '2 thìa cà phê đường',
#    'sả băm',
#    'tỏi băm',
#    'rau húng lủi trang trí'],
#   'step': ['Bước 1: Ốc đỏ làm sạch. Sả cây cắt khúc, đập giập. Bắc chảo lên bếp, cho bơ vào, đợi bơ tan cho tỏi, sả băm vào phi thơm. Cho sả cây vào xào sau đó cho ốc vào xóc đều. Đổ tiếp sữa vào, nêm thêm hạt nêm, đường vừa ăn, để lửa riu riu. Khi ốc chín, trút ra đĩa, trang trí thêm rau húng lủi lên mặt',
#    'Bước 2: Mách nhỏ: Nếu mua ốc đỏ đông lạnh nên chịu khó chọn và ngửi từng con để đảm bảo ốc thật tươi. Có thể dùng tay bấm vào thịt ốc, cảm thấy cứng và chắc là được'],
#   'note': [],
#   'post_date': 'Thứ hai, 4/10/2021, 11:35 (GMT+7)'},
#  {'link': 'https://vnexpress.net/cay-cay-mon-oc-4311274.html',
#   'type_of_food': 'Món ngon cho cuối tuần',
#   'title': 'Ốc giác nấu cà ri',
#   'description': 'Nấu các món ốc, phải có chút cay cay từ sả, ớt mới ngon. Xét ở góc độ ẩm thực, đó là sự quân bình âm dương nhưng với người thưởng thức, có tí xuýt xoa, hít hà thì càng thêm đã miệng.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 16,
#   'ingredients': ['1 con ốc giác (khoảng 300 g)',
#    '1 chén nước cốt dừa',
#    '1 trái ớt sừng',
#    '2 cây sả',
#    '1 ít gừng giã giập',
#    '2 thìa cà-phê bột cà ri',
#    '1 thìa súp sả băm',
#    '1 thìa cà-phê tỏi băm',
#    '1 thìa cà-phê củ hành băm',
#    '1 thìa cà-phê đường',
#    '2 thìa cà-phê hạt nêm',
#    '2 thìa cà-phê nước cốt me',
#    '1 thìa cà-phê nước mắm',
#    '1 thìa súp dầu ăn',
#    'đậu phộng rang',
#    'rau răm ăn kèm'],
#   'step': ['Bước 1: Ốc giác trụng sơ với ít gừng giã giập, vớt ra, để ráo, vít lấy phần thịt ốc. Ớt sừng xắt lát. Sả cây cắt khúc, đập giập. Bắc chảo, phi thơm tỏi, sả, ớt, củ hành băm với dầu ăn, cho sả cây và bột cà ri vào xào sau đó đổ nước cốt dừa vào nấu sôi',
#    'Bước 2: Cho tiếp ốc vào, nêm hạt nêm, đường, nước mắm, nước cốt me vừa ăn, để lửa riu riu. Nấu đến khi nước sền sệt là được, tắt bếp, nhấc xuống. Trút ốc ra đĩa, rắc đậu phộng giã giập và ớt lên. Dùng kèm rau răm',
#    'Bước 3: Mách nhỏ: Ốc giác chọn con vừa ăn, không nên chọn con quá to sẽ bị nhớt. Khi vít lấy thịt ốc nên nhẹ tay, tránh làm vỡ mật sẽ làm món bị đắng mất ngon'],
#   'note': [],
#   'post_date': 'Thứ hai, 4/10/2021, 11:35 (GMT+7)'},
#  {'link': 'https://vnexpress.net/sinh-to-tu-rau-qua-4311296.html',
#   'type_of_food': 'Món tráng miệng, giải khát',
#   'title': 'Bắp cải và táo',
#   'description': 'Ngon, có lợi cho sức khỏe là công dụng của các loại thức uống dưới đây. Bạn hãy bắt tay vào làm để cùng thưởng thức nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 5,
#   'ingredients': ['Nguyên liệu: 150 g bắp cải',
#    '1/2 quả táo',
#    '1/2 quả chanh',
#    'đường',
#    'đá viên'],
#   'step': ['Bước 1: Bắp cải rửa sạch, thái sợi, cho vào máy xay ép lấy nước. Táo bỏ vỏ, cuống và hạt, thái miếng nhỏ. Dùng máy xay táo thật nhuyễn, thêm nước ép bắp cải, nước cốt chanh. Thêm vào một ít đường và đá viên, tùy theo sở thích',
#    'Bước 2: Công dụng: Thức uống này có tác dụng nhuận trường, thúc đấy quá trình trao đổi chất, bài tiết chất độc trong cơ thể'],
#   'note': [],
#   'post_date': 'Thứ ba, 26/10/2021, 11:18 (GMT+7)'},
#  {'link': 'https://vnexpress.net/sinh-to-tu-rau-qua-4311296.html',
#   'type_of_food': 'Món tráng miệng, giải khát',
#   'title': 'Yoghurt và rau cần',
#   'description': 'Ngon, có lợi cho sức khỏe là công dụng của các loại thức uống dưới đây. Bạn hãy bắt tay vào làm để cùng thưởng thức nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 5,
#   'ingredients': ['Nguyên liệu: 300 g rau cần',
#    '1 thìa súp yoghurt',
#    '5 quả cà chua bi',
#    'đường',
#    'đá viên'],
#   'step': ['Bước 1: Rau cần bỏ lá sâu, rửa sạch. Cà chua rửa sạch, bổ đôi, cho vào máy xay nhuyễn cùng rau cần, lược lấy nước cốt, bỏ xác. Cho yoghurt vào ly, thêm nước rau ép. Tùy theo sở thích mà thêm đường, đá viên',
#    'Bước 2: Công dụng: Yoghurt, cần chứa vitamin B1, B2, chất khoáng và chất xơ. Giúp giảm stress, căng thẳng'],
#   'note': [],
#   'post_date': 'Thứ ba, 26/10/2021, 11:18 (GMT+7)'},
#  {'link': 'https://vnexpress.net/sinh-to-tu-rau-qua-4311296.html',
#   'type_of_food': 'Món tráng miệng, giải khát',
#   'title': 'Cà rốt và cần tây',
#   'description': 'Ngon, có lợi cho sức khỏe là công dụng của các loại thức uống dưới đây. Bạn hãy bắt tay vào làm để cùng thưởng thức nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 4,
#   'ingredients': ['Nguyên liệu: 1 củ cà rốt',
#    '50 g cần tây',
#    '1 thìa cà phê mật ong',
#    'đá viên'],
#   'step': ['Bước 1: Cà rốt bào vỏ, rửa sạch, thái thành thanh dài, ép lấy nước cốt. Cần tây lấy thân, tước bỏ xơ bên ngoài, rửa sạch, thái lát mỏng. Cho cần tây và nước cà',
#    'Bước 2: rốt vào máy xay ở tốc độ cao. Thêm mật ong và đá viên vào xay chung đến khi hỗn hợp thật mịn',
#    'Bước 3: Công dụng: Loại nước này có tác dụng bồi dưỡng cơ thể, giảm huyết, bổ sung vitamin A và khoáng chất, chất xơ'],
#   'note': [],
#   'post_date': 'Thứ ba, 26/10/2021, 11:18 (GMT+7)'},
#  {'link': 'https://vnexpress.net/sinh-to-tu-rau-qua-4311296.html',
#   'type_of_food': 'Món tráng miệng, giải khát',
#   'title': 'Đu đủ và bắp cải tím',
#   'description': 'Ngon, có lợi cho sức khỏe là công dụng của các loại thức uống dưới đây. Bạn hãy bắt tay vào làm để cùng thưởng thức nhé.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 6,
#   'ingredients': ['Nguyên liệu: 1/4 quả đu đủ',
#    '20g bắp cải tím',
#    '50ml sữa tươi',
#    'đường',
#    'đá viên',
#    'muối'],
#   'step': ['Bước 1: Đu đủ gọt bỏ vỏ, hạt, thái miếng nhỏ. Bắp cải tím rửa sạch trong nước muối, vẩy ráo, thái nhỏ. Cho đu đủ, bắp cải, sữa tươi vào máy xay nhuyễn. Nếu muốn ngọt hơn, bạn có thể cho thêm đường, thêm đá viên hay đá bào vào',
#    'Bước 2: Công dụng: Loại sinh tố này giúp thanh mát cơ thể. Đu đủ chứa nhiều enzyme, rất tốt cho hệ tiêu hóa'],
#   'note': [],
#   'post_date': 'Thứ ba, 26/10/2021, 11:18 (GMT+7)'},
#  {'link': 'https://vnexpress.net/mon-trang-mieng-4311313.html',
#   'type_of_food': 'Món tráng miệng, giải khát',
#   'title': 'Dưa hấu trộn mật ong',
#   'description': 'Dưa hấu trộn mật ong và đào ngâm rượu vang là hai món tráng miệng vừa bổ mát, ngon miệng lại rất dễ làm.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 3,
#   'ingredients': ['1 kg dưa hấu',
#    '5 muỗng cà phê mật ong',
#    'muối tinh một ít'],
#   'step': ['Bước 1: Dưa hấu gọt vỏ, bỏ hạt, xắt hạt lựu (hoặc có thể miết nhuyễn tùy vào khẩu vị từng gia đình), trộn đều với ít muối tinh và mật ong',
#    'Bước 2: Cho vào tủ lạnh trước khi dùng'],
#   'note': [],
#   'post_date': 'Thứ ba, 26/10/2021, 11:01 (GMT+7)'},
#  {'link': 'https://vnexpress.net/mon-trang-mieng-4311313.html',
#   'type_of_food': 'Món tráng miệng, giải khát',
#   'title': 'Đào dầm rượu vang',
#   'description': 'Dưa hấu trộn mật ong và đào ngâm rượu vang là hai món tráng miệng vừa bổ mát, ngon miệng lại rất dễ làm.',
#   'author_name': None,
#   'cook_time': None,
#   'num_of_people': None,
#   'calories': None,
#   'num_of_ingredients': 7,
#   'ingredients': ['300 g đào đỏ (hoặc mận)',
#    '2 muỗng cà phê nước cốt chanh',
#    '100 g đường',
#    'ít bột va ni',
#    '50 ml rượu vang trắng',
#    '20 ml si rô nho',
#    '100 ml nước sôi để nguội'],
#   'step': ['Bước 1: Đào rửa sạch, tách hạt, xắt hạt lựu',
#    'Bước 2: Trộn đều đào với đường, nêm nước cốt chanh và rượu vang trắng, đảo đều cho ngấm, cho vào ngăn mát tủ lạnh, để khoảng 1 giờ',
#    'Bước 3: Hòa rượu vang với nước sôi để nguội rồi đổ vào âu đào, trộn đều và thưởng thức'],
#   'note': [],
#   'post_date': 'Thứ ba, 26/10/2021, 11:01 (GMT+7)'}]

# %%
len(all_foods_details)
# Out:
# 152

# %%
all_foods_detail_df = pd.DataFrame(all_foods_details)
#all_foods_detail_df.to_csv('vnexpress_foods_detail_filled.csv', index=False)

# %%
all_foods_detail_df
# Out:
#                                                   link  \
# 0    https://vnexpress.net/cach-che-bien-vai-mon-au...
# 1    https://vnexpress.net/cach-che-bien-vai-mon-au...
# 2    https://vnexpress.net/cach-che-bien-vai-mon-au...
# 3    https://vnexpress.net/cach-che-bien-vai-mon-au...
# 4    https://vnexpress.net/nhung-mon-ngon-cho-mua-h...
# ..                                                 ...
# 147  https://vnexpress.net/sinh-to-tu-rau-qua-43112...
# 148  https://vnexpress.net/sinh-to-tu-rau-qua-43112...
# 149  https://vnexpress.net/sinh-to-tu-rau-qua-43112...
# 150  https://vnexpress.net/mon-trang-mieng-4311313....
# 151  https://vnexpress.net/mon-trang-mieng-4311313....
#
#                    type_of_food                      title  \
# 0            Món ngon hàng ngày           Lẩu hải sản Pháp
# 1            Món ngon hàng ngày                  Mỳ bò băm
# 2            Món ngon hàng ngày              Cơm chiên nho
# 3            Món ngon hàng ngày           Hàu sốt bơ chanh
# 4            Món ngon hàng ngày    Canh rong biển sườn non
# ..                          ...                        ...
# 147  Món tráng miệng, giải khát       Yoghurt và rau cần
# 148  Món tráng miệng, giải khát      Cà rốt và cần tây
# 149  Món tráng miệng, giải khát  Đu đủ và bắp cải tím
# 150  Món tráng miệng, giải khát       Dưa hấu trộn mật ong
# 151  Món tráng miệng, giải khát          Đào dầm rượu vang
#
#                                            description author_name cook_time  \
# 0    Các món ăn Âu dưới đây mang phong cách pha trộ...        None      None
# 1    Các món ăn Âu dưới đây mang phong cách pha trộ...        None      None
# 2    Các món ăn Âu dưới đây mang phong cách pha trộ...        None      None
# 3    Các món ăn Âu dưới đây mang phong cách pha trộ...        None      None
# 4    Canh rong biển sườn non, bò kho ớt, bí đỏ xào ...        None      None
# ..                                                 ...         ...       ...
# 147  Ngon, có lợi cho sức khỏe là công dụng c...        None      None
# 148  Ngon, có lợi cho sức khỏe là công dụng c...        None      None
# 149  Ngon, có lợi cho sức khỏe là công dụng c...        None      None
# 150  Dưa hấu trộn mật ong và đào ngâm rượu vang là ...        None      None
# 151  Dưa hấu trộn mật ong và đào ngâm rượu vang là ...        None      None
#
#     num_of_people calories  num_of_ingredients  \
# 0            None     None                 9.0
# 1            None     None                 8.0
# 2            None     None                 7.0
# 3            None     None                 6.0
# 4            None     None                 8.0
# ..            ...      ...                 ...
# 147          None     None                 5.0
# 148          None     None                 4.0
# 149          None     None                 6.0
# 150          None     None                 3.0
# 151          None     None                 7.0
#
#                                            ingredients  \
# 0    [Tôm 200 g, nghêu 200 g, mực 200 g, cà 200 g, ...
# 1    [Mỳ Ý 100 g, cà chua 200 g, thịt bò 200 g, hàn...
# 2    [Cơm trắng 200 g, nho 100 g, cà rốt 30 g, bắp ...
# 3    [Hàu 1 kg, bơ 50 g, chanh 10 g, đường 10 g, ng...
# 4    [200 g sườn non, 50 rong biển (loại nấu canh),...
# ..                                                 ...
# 147  [Nguyên liệu: 300 g rau cần, 1 thìa súp yo...
# 148  [Nguyên liệu: 1 củ cà rốt, 50 g cần tây, ...
# 149  [Nguyên liệu: 1/4 quả đu đủ, 20g bắp cải ...
# 150  [1 kg dưa hấu, 5 muỗng cà phê mật ong, muối ti...
# 151  [300 g đào đỏ (hoặc mận), 2 muỗng cà phê nước ...
#
#                                                   step note  \
# 0    [Bước 1: Xào cà chua cho thơm, đổ rượu vang và...   []
# 1    [Bước 1: Luộc mì Ý trong nước sôi khoảng 8 phú...   []
# 2    [Bước 1: Đặt chảo lên bếp, chờ chảo nóng cho b...   []
# 3    [Bước 1: Hàu rửa sạch, tách vỏ ra làm đôi. Hàn...   []
# 4    [Bước 1: Sườn non chà muối cho sạch, rửa rồi đ...   []
# ..                                                 ...  ...
# 147  [Bước 1: Rau cần bỏ lá sâu, rửa sạch. Cà...   []
# 148  [Bước 1: Cà rốt bào vỏ, rửa sạch, thái ...   []
# 149  [Bước 1: Đu đủ gọt bỏ vỏ, hạt, thái miế...   []
# 150  [Bước 1: Dưa hấu gọt vỏ, bỏ hạt, xắt hạt lựu (...   []
# 151  [Bước 1: Đào rửa sạch, tách hạt, xắt hạt lựu, ...   []
#
#                               post_date
# 0    Thứ hai, 22/11/2021, 10:22 (GMT+7)
# 1    Thứ hai, 22/11/2021, 10:22 (GMT+7)
# 2    Thứ hai, 22/11/2021, 10:22 (GMT+7)
# 3    Thứ hai, 22/11/2021, 10:22 (GMT+7)
# 4    Thứ năm, 18/11/2021, 15:44 (GMT+7)
# ..                                  ...
# 147   Thứ ba, 26/10/2021, 11:18 (GMT+7)
# 148   Thứ ba, 26/10/2021, 11:18 (GMT+7)
# 149   Thứ ba, 26/10/2021, 11:18 (GMT+7)
# 150   Thứ ba, 26/10/2021, 11:01 (GMT+7)
# 151   Thứ ba, 26/10/2021, 11:01 (GMT+7)
#
# [152 rows x 13 columns]

# %% [markdown]
# ### Merge data

# %%
raw_data_df = pd.read_csv('vnexpress_foods_detail.csv') 
filtered_data_df = all_foods_detail_df


# filter out rows in A with empty 'step'
mask = raw_data_df.apply(
    lambda row: row['step'] in ([], "[]"),
    axis=1
)
raw_data_df_filtered = raw_data_df[~mask].reset_index(drop=True)

# check duplicate urls between A and B
# get urls in A
existing_urls = set(raw_data_df_filtered['link'])

# Keep only rows in B whose 'url' is not in A
filtered_data_df_unique = filtered_data_df[~filtered_data_df['link'].isin(existing_urls)].reset_index(drop=True)

# concatenate
final_table = pd.concat([raw_data_df_filtered, filtered_data_df_unique], ignore_index=True)

final_table.to_csv('vnexpress_foods_detail_merged.csv', index=False)

print(f"""
- Old table A: {len(raw_data_df)}
- Removed empty step rows: {mask.sum()}
- Table B (filled): {len(filtered_data_df)}
- Duplicates removed from B: {len(filtered_data_df) - len(filtered_data_df_unique)}
- Final merged table: {len(final_table)}
""")
# Out:
# - Old table A: 810
# - Removed empty step rows: 69
# - Table B (filled): 152
# - Duplicates removed from B: 0
# - Final merged table: 893
